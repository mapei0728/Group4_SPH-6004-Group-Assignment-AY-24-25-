# %%
# Standard Libraries 
import os
import random
import pickle
from typing import Dict, List

# Third-Party Libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# PyTorch 
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# Evaluation (sklearn) 
from sklearn.metrics import (
    accuracy_score,
    average_precision_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score
)

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
data = np.load("mimic_embed_data.npz")
train_embeddings = data["train_embeddings"]
train_labels = data["train_labels"]
valid_embeddings = data["valid_embeddings"]
valid_labels = data["valid_labels"]
test_embeddings = data["test_embeddings"]
test_labels = data["test_labels"]

# %%
class SingleLabelDataset(Dataset):
    def __init__(self, embeddings, labels):
        self.embeddings = torch.tensor(embeddings, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.float32)

    def __len__(self):
        return len(self.embeddings)

    def __getitem__(self, idx):
        return {
            "embedding": self.embeddings[idx],
            "lab": self.labels[idx].unsqueeze(0)  #  shape: (1,)
        }

# %%
def get_single_label_data(embeddings, labels, label_idx):
    mask = ~np.isnan(labels[:, label_idx])
    return embeddings[mask], labels[mask, label_idx]

# %%
class TabTransformer(nn.Module):
    def __init__(self, input_dim=1376, hidden_dim=128, output_dim=1, nhead=8, nlayers=4, dropout=0.1):
        super(TabTransformer, self).__init__()

        self.input_proj = nn.Linear(input_dim, hidden_dim)
        self.norm = nn.LayerNorm(hidden_dim)

        encoder_layer = self._build_encoder_layer(hidden_dim, nhead, dropout)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=nlayers)

        self.classifier = nn.Linear(hidden_dim, output_dim)

    def _build_encoder_layer(self, hidden_dim, nhead, dropout):
        return nn.TransformerEncoderLayer(
            d_model=hidden_dim,
            nhead=nhead,
            dim_feedforward=hidden_dim * 8,
            dropout=dropout,
            activation='gelu',
            batch_first=True
        )

    def forward(self, x):
        x = self.input_proj(x)
        x = self.norm(x)
        x = x.unsqueeze(1)
        x = self.encoder(x)
        x = x.squeeze(1)
        return self.classifier(x)

# %%
class MaskedAsymmetricLoss(nn.Module):
    def __init__(self, gamma_pos=0, gamma_neg=4):
        super().__init__()
        self.gamma_pos = gamma_pos
        self.gamma_neg = gamma_neg

    def forward(self, logits, labels, mask):
        probs = torch.sigmoid(logits)
        # Positive loss
        pos_loss = labels * torch.pow(1 - probs, self.gamma_pos) * torch.log(probs + 1e-8)
        # Negative loss
        neg_loss = (1 - labels) * torch.pow(probs, self.gamma_neg) * torch.log(1 - probs + 1e-8)
        # Combined loss
        loss = - (pos_loss + neg_loss)
        # Apply mask
        return (loss * mask).sum() / mask.sum()

# %%
def train_single_label_model(train_loader, val_loader, label_name, save_path, gamma_pos, gamma_neg):
    print(f" Training with gamma_pos={gamma_pos}, gamma_neg={gamma_neg}")
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = TabTransformer().to(device)
    criterion = MaskedAsymmetricLoss(gamma_pos=gamma_pos, gamma_neg=gamma_neg)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

    for epoch in range(15):
        model.train()
        total_loss = 0

        for batch in train_loader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device).float().view(-1, 1)  # 保证 batch_size x 1
            mask = torch.ones_like(y)

            logits = model(x)
            loss = criterion(logits, y, mask)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"[{label_name}] Epoch {epoch+1} - Training loss: {avg_loss:.4f}")

    torch.save(model.state_dict(), save_path)
    print(f" Model for {label_name} saved to {save_path}")

    return model

# %%
def grid_search_asl_for_label(label_index, label_name, gamma_pos_list, gamma_neg_list):
    print(f"\n Grid search for label: {label_name}")
    
    # Get training and validation data for the specific label
    train_X, train_y = get_single_label_data(train_embeddings, train_labels, label_index)
    val_X, val_y = get_single_label_data(valid_embeddings, valid_labels, label_index)

    train_ds = SingleLabelDataset(train_X, train_y)
    val_ds = SingleLabelDataset(val_X, val_y)
    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=32, shuffle=False)

    best_ap = 0
    best_config = None

    for gamma_pos in gamma_pos_list:
        for gamma_neg in gamma_neg_list:
            print(f"→ gamma_pos={gamma_pos}, gamma_neg={gamma_neg}")

            # Initialize model
            model = TabTransformer().to(device)
            criterion = MaskedAsymmetricLoss(gamma_pos=gamma_pos, gamma_neg=gamma_neg)
            optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

            # Train for a few epochs to evaluate config
            for epoch in range(8):
                model.train()
                for batch in train_loader:
                    x = batch["embedding"].to(device)
                    y = batch["lab"].to(device).float().view(-1, 1) 
                    mask = torch.ones_like(y)
                    logits = model(x)
                    loss = criterion(logits, y, mask)
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

            # Evaluate on validation set using Average Precision
            model.eval()
            all_probs = []
            all_labels = []
            with torch.no_grad():
                for batch in val_loader:
                    x = batch["embedding"].to(device)
                    y = batch["lab"].to(device).float().view(-1, 1) 
                    logits = model(x)
                    probs = torch.sigmoid(logits).squeeze()
                    all_probs.extend(probs.cpu().numpy())
                    all_labels.extend(y.cpu().numpy())

            ap = average_precision_score(all_labels, all_probs)
            print(f"    → AP={ap:.4f}")

            if ap > best_ap:
                best_ap = ap
                best_config = (gamma_pos, gamma_neg)

    print(f" Best config for {label_name}: gamma_pos={best_config[0]}, gamma_neg={best_config[1]} with AP={best_ap:.4f}")
    return best_config

# %%
label_names =  [
    "Enlarged Cardiomediastinum", "Cardiomegaly", "Lung Opacity", "Lung Lesion",
    "Edema", "Consolidation", "Pneumonia", "Atelectasis",
    "Pneumothorax", "Pleural Effusion", "Pleural Other", "Fracture", "Support Devices"
]

gamma_pos_list = [0.0, 0.5]
gamma_neg_list = [3.0, 4.0, 5.0, 6.0]

search_results = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for i, label_name in enumerate(label_names):
    print(f"\n Running ASL grid search for label: {label_name}")

    best_gamma_pos, best_gamma_neg = grid_search_asl_for_label(
        i, label_name, gamma_pos_list, gamma_neg_list
    )

    # Train final model with best gamma combination
    train_X, train_y = get_single_label_data(train_embeddings, train_labels, i)
    val_X, val_y = get_single_label_data(valid_embeddings, valid_labels, i)

    train_ds = SingleLabelDataset(train_X, train_y)
    val_ds = SingleLabelDataset(val_X, val_y)

    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=32, shuffle=False)

    model_path = f"transformer_label_{i}_{label_name}.pt"
    model = train_single_label_model(train_loader, val_loader, label_name, model_path,
                                    gamma_pos=best_gamma_pos, gamma_neg=best_gamma_neg)

    # Save best config for this label
    search_results.append({
        "label": label_name,
        "gamma_pos": best_gamma_pos,
        "gamma_neg": best_gamma_neg
    })

# Save all best gamma configurations to CSV
import pandas as pd
pd.DataFrame(search_results).to_csv("best_gamma_config_per_label.csv", index=False)
print("\n All best gamma configs saved to best_gamma_config_per_label.csv")
# Out:
#  Running ASL grid search for label: Enlarged Cardiomediastinum
#
#  Grid search for label: Enlarged Cardiomediastinum
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.5534
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.5526
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.5421
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.5431
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.5511
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.5466
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.5372
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.5408
#  Best config for Enlarged Cardiomediastinum: gamma_pos=0.0, gamma_neg=3.0 with AP=0.5534
#  Training with gamma_pos=0.0, gamma_neg=3.0
# [Enlarged Cardiomediastinum] Epoch 1 - Training loss: 0.1084
# [Enlarged Cardiomediastinum] Epoch 2 - Training loss: 0.1007
# [Enlarged Cardiomediastinum] Epoch 3 - Training loss: 0.0996
# [Enlarged Cardiomediastinum] Epoch 4 - Training loss: 0.0987
# [Enlarged Cardiomediastinum] Epoch 5 - Training loss: 0.0985
# [Enlarged Cardiomediastinum] Epoch 6 - Training loss: 0.0980
# [Enlarged Cardiomediastinum] Epoch 7 - Training loss: 0.0977
# [Enlarged Cardiomediastinum] Epoch 8 - Training loss: 0.0976
# [Enlarged Cardiomediastinum] Epoch 9 - Training loss: 0.0970
# [Enlarged Cardiomediastinum] Epoch 10 - Training loss: 0.0971
# [Enlarged Cardiomediastinum] Epoch 11 - Training loss: 0.0966
# [Enlarged Cardiomediastinum] Epoch 12 - Training loss: 0.0961
# [Enlarged Cardiomediastinum] Epoch 13 - Training loss: 0.0959
# [Enlarged Cardiomediastinum] Epoch 14 - Training loss: 0.0955
# [Enlarged Cardiomediastinum] Epoch 15 - Training loss: 0.0953
#  Model for Enlarged Cardiomediastinum saved to transformer_label_0_Enlarged Cardiomediastinum.pt
#
#  Running ASL grid search for label: Cardiomegaly
#
#  Grid search for label: Cardiomegaly
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.5708
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.5780
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.5776
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.5772
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.5832
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.5791
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.5838
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.5824
#  Best config for Cardiomegaly: gamma_pos=0.5, gamma_neg=5.0 with AP=0.5838
#  Training with gamma_pos=0.5, gamma_neg=5.0
# [Cardiomegaly] Epoch 1 - Training loss: 0.0537
# [Cardiomegaly] Epoch 2 - Training loss: 0.0509
# [Cardiomegaly] Epoch 3 - Training loss: 0.0500
# [Cardiomegaly] Epoch 4 - Training loss: 0.0496
# [Cardiomegaly] Epoch 5 - Training loss: 0.0495
# [Cardiomegaly] Epoch 6 - Training loss: 0.0492
# [Cardiomegaly] Epoch 7 - Training loss: 0.0488
# [Cardiomegaly] Epoch 8 - Training loss: 0.0488
# [Cardiomegaly] Epoch 9 - Training loss: 0.0487
# [Cardiomegaly] Epoch 10 - Training loss: 0.0486
# [Cardiomegaly] Epoch 11 - Training loss: 0.0484
# [Cardiomegaly] Epoch 12 - Training loss: 0.0483
# [Cardiomegaly] Epoch 13 - Training loss: 0.0482
# [Cardiomegaly] Epoch 14 - Training loss: 0.0480
# [Cardiomegaly] Epoch 15 - Training loss: 0.0483
#  Model for Cardiomegaly saved to transformer_label_1_Cardiomegaly.pt
#
#  Running ASL grid search for label: Lung Opacity
#
#  Grid search for label: Lung Opacity
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.3943
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.4047
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.4146
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.4021
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.4075
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.4100
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.4001
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.4154
#  Best config for Lung Opacity: gamma_pos=0.5, gamma_neg=6.0 with AP=0.4154
#  Training with gamma_pos=0.5, gamma_neg=6.0
# [Lung Opacity] Epoch 1 - Training loss: 0.0156
# [Lung Opacity] Epoch 2 - Training loss: 0.0143
# [Lung Opacity] Epoch 3 - Training loss: 0.0142
# [Lung Opacity] Epoch 4 - Training loss: 0.0139
# [Lung Opacity] Epoch 5 - Training loss: 0.0138
# [Lung Opacity] Epoch 6 - Training loss: 0.0137
# [Lung Opacity] Epoch 7 - Training loss: 0.0137
# [Lung Opacity] Epoch 8 - Training loss: 0.0135
# [Lung Opacity] Epoch 9 - Training loss: 0.0136
# [Lung Opacity] Epoch 10 - Training loss: 0.0133
# [Lung Opacity] Epoch 11 - Training loss: 0.0135
# [Lung Opacity] Epoch 12 - Training loss: 0.0135
# [Lung Opacity] Epoch 13 - Training loss: 0.0132
# [Lung Opacity] Epoch 14 - Training loss: 0.0130
# [Lung Opacity] Epoch 15 - Training loss: 0.0130
#  Model for Lung Opacity saved to transformer_label_2_Lung Opacity.pt
#
#  Running ASL grid search for label: Lung Lesion
#
#  Grid search for label: Lung Lesion
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.4267
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.4413
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.4262
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.4232
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.4224
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.4081
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.4310
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.4224
#  Best config for Lung Lesion: gamma_pos=0.0, gamma_neg=4.0 with AP=0.4413
#  Training with gamma_pos=0.0, gamma_neg=4.0
# [Lung Lesion] Epoch 1 - Training loss: 0.0316
# [Lung Lesion] Epoch 2 - Training loss: 0.0280
# [Lung Lesion] Epoch 3 - Training loss: 0.0273
# [Lung Lesion] Epoch 4 - Training loss: 0.0272
# [Lung Lesion] Epoch 5 - Training loss: 0.0269
# [Lung Lesion] Epoch 6 - Training loss: 0.0269
# [Lung Lesion] Epoch 7 - Training loss: 0.0268
# [Lung Lesion] Epoch 8 - Training loss: 0.0265
# [Lung Lesion] Epoch 9 - Training loss: 0.0263
# [Lung Lesion] Epoch 10 - Training loss: 0.0260
# [Lung Lesion] Epoch 11 - Training loss: 0.0261
# [Lung Lesion] Epoch 12 - Training loss: 0.0257
# [Lung Lesion] Epoch 13 - Training loss: 0.0256
# [Lung Lesion] Epoch 14 - Training loss: 0.0252
# [Lung Lesion] Epoch 15 - Training loss: 0.0253
#  Model for Lung Lesion saved to transformer_label_3_Lung Lesion.pt
#
#  Running ASL grid search for label: Edema
#
#  Grid search for label: Edema
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.2338
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.2179
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.2182
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.2371
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.2272
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.2221
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.2116
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.2055
#  Best config for Edema: gamma_pos=0.0, gamma_neg=6.0 with AP=0.2371
#  Training with gamma_pos=0.0, gamma_neg=6.0
# [Edema] Epoch 1 - Training loss: 0.0206
# [Edema] Epoch 2 - Training loss: 0.0192
# [Edema] Epoch 3 - Training loss: 0.0190
# [Edema] Epoch 4 - Training loss: 0.0187
# [Edema] Epoch 5 - Training loss: 0.0187
# [Edema] Epoch 6 - Training loss: 0.0186
# [Edema] Epoch 7 - Training loss: 0.0185
# [Edema] Epoch 8 - Training loss: 0.0185
# [Edema] Epoch 9 - Training loss: 0.0184
# [Edema] Epoch 10 - Training loss: 0.0183
# [Edema] Epoch 11 - Training loss: 0.0182
# [Edema] Epoch 12 - Training loss: 0.0183
# [Edema] Epoch 13 - Training loss: 0.0182
# [Edema] Epoch 14 - Training loss: 0.0180
# [Edema] Epoch 15 - Training loss: 0.0180
#  Model for Edema saved to transformer_label_4_Edema.pt
#
#  Running ASL grid search for label: Consolidation
#
#  Grid search for label: Consolidation
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.1490
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.1502
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.1537
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.1641
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.1426
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.1471
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.1507
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.1431
#  Best config for Consolidation: gamma_pos=0.0, gamma_neg=6.0 with AP=0.1641
#  Training with gamma_pos=0.0, gamma_neg=6.0
# [Consolidation] Epoch 1 - Training loss: 0.0290
# [Consolidation] Epoch 2 - Training loss: 0.0276
# [Consolidation] Epoch 3 - Training loss: 0.0273
# [Consolidation] Epoch 4 - Training loss: 0.0270
# [Consolidation] Epoch 5 - Training loss: 0.0271
# [Consolidation] Epoch 6 - Training loss: 0.0267
# [Consolidation] Epoch 7 - Training loss: 0.0266
# [Consolidation] Epoch 8 - Training loss: 0.0266
# [Consolidation] Epoch 9 - Training loss: 0.0264
# [Consolidation] Epoch 10 - Training loss: 0.0263
# [Consolidation] Epoch 11 - Training loss: 0.0261
# [Consolidation] Epoch 12 - Training loss: 0.0263
# [Consolidation] Epoch 13 - Training loss: 0.0259
# [Consolidation] Epoch 14 - Training loss: 0.0258
# [Consolidation] Epoch 15 - Training loss: 0.0256
#  Model for Consolidation saved to transformer_label_5_Consolidation.pt
#
#  Running ASL grid search for label: Pneumonia
#
#  Grid search for label: Pneumonia
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.3843
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.3927
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.3770
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.3865
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.3752
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.3810
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.3755
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.3789
#  Best config for Pneumonia: gamma_pos=0.0, gamma_neg=4.0 with AP=0.3927
#  Training with gamma_pos=0.0, gamma_neg=4.0
# [Pneumonia] Epoch 1 - Training loss: 0.0426
# [Pneumonia] Epoch 2 - Training loss: 0.0402
# [Pneumonia] Epoch 3 - Training loss: 0.0396
# [Pneumonia] Epoch 4 - Training loss: 0.0394
# [Pneumonia] Epoch 5 - Training loss: 0.0394
# [Pneumonia] Epoch 6 - Training loss: 0.0392
# [Pneumonia] Epoch 7 - Training loss: 0.0389
# [Pneumonia] Epoch 8 - Training loss: 0.0387
# [Pneumonia] Epoch 9 - Training loss: 0.0389
# [Pneumonia] Epoch 10 - Training loss: 0.0386
# [Pneumonia] Epoch 11 - Training loss: 0.0385
# [Pneumonia] Epoch 12 - Training loss: 0.0380
# [Pneumonia] Epoch 13 - Training loss: 0.0380
# [Pneumonia] Epoch 14 - Training loss: 0.0377
# [Pneumonia] Epoch 15 - Training loss: 0.0376
#  Model for Pneumonia saved to transformer_label_6_Pneumonia.pt
#
#  Running ASL grid search for label: Atelectasis
#
#  Grid search for label: Atelectasis
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.5461
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.5420
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.5470
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.5528
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.5436
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.5526
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.5435
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.5472
#  Best config for Atelectasis: gamma_pos=0.0, gamma_neg=6.0 with AP=0.5528
#  Training with gamma_pos=0.0, gamma_neg=6.0
# [Atelectasis] Epoch 1 - Training loss: 0.0899
# [Atelectasis] Epoch 2 - Training loss: 0.0864
# [Atelectasis] Epoch 3 - Training loss: 0.0864
# [Atelectasis] Epoch 4 - Training loss: 0.0861
# [Atelectasis] Epoch 5 - Training loss: 0.0856
# [Atelectasis] Epoch 6 - Training loss: 0.0855
# [Atelectasis] Epoch 7 - Training loss: 0.0852
# [Atelectasis] Epoch 8 - Training loss: 0.0846
# [Atelectasis] Epoch 9 - Training loss: 0.0847
# [Atelectasis] Epoch 10 - Training loss: 0.0844
# [Atelectasis] Epoch 11 - Training loss: 0.0845
# [Atelectasis] Epoch 12 - Training loss: 0.0841
# [Atelectasis] Epoch 13 - Training loss: 0.0840
# [Atelectasis] Epoch 14 - Training loss: 0.0837
# [Atelectasis] Epoch 15 - Training loss: 0.0834
#  Model for Atelectasis saved to transformer_label_7_Atelectasis.pt
#
#  Running ASL grid search for label: Pneumothorax
#
#  Grid search for label: Pneumothorax
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.7173
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.7152
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.7192
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.7176
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.7259
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.7184
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.7175
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.7159
#  Best config for Pneumothorax: gamma_pos=0.5, gamma_neg=3.0 with AP=0.7259
#  Training with gamma_pos=0.5, gamma_neg=3.0
# [Pneumothorax] Epoch 1 - Training loss: 0.0620
# [Pneumothorax] Epoch 2 - Training loss: 0.0570
# [Pneumothorax] Epoch 3 - Training loss: 0.0563
# [Pneumothorax] Epoch 4 - Training loss: 0.0559
# [Pneumothorax] Epoch 5 - Training loss: 0.0553
# [Pneumothorax] Epoch 6 - Training loss: 0.0549
# [Pneumothorax] Epoch 7 - Training loss: 0.0545
# [Pneumothorax] Epoch 8 - Training loss: 0.0542
# [Pneumothorax] Epoch 9 - Training loss: 0.0538
# [Pneumothorax] Epoch 10 - Training loss: 0.0535
# [Pneumothorax] Epoch 11 - Training loss: 0.0534
# [Pneumothorax] Epoch 12 - Training loss: 0.0533
# [Pneumothorax] Epoch 13 - Training loss: 0.0526
# [Pneumothorax] Epoch 14 - Training loss: 0.0525
# [Pneumothorax] Epoch 15 - Training loss: 0.0521
#  Model for Pneumothorax saved to transformer_label_8_Pneumothorax.pt
#
#  Running ASL grid search for label: Pleural Effusion
#
#  Grid search for label: Pleural Effusion
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.3769
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.3434
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.3418
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.3372
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.3115
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.3998
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.3663
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.3696
#  Best config for Pleural Effusion: gamma_pos=0.5, gamma_neg=4.0 with AP=0.3998
#  Training with gamma_pos=0.5, gamma_neg=4.0
# [Pleural Effusion] Epoch 1 - Training loss: 0.0142
# [Pleural Effusion] Epoch 2 - Training loss: 0.0134
# [Pleural Effusion] Epoch 3 - Training loss: 0.0129
# [Pleural Effusion] Epoch 4 - Training loss: 0.0128
# [Pleural Effusion] Epoch 5 - Training loss: 0.0125
# [Pleural Effusion] Epoch 6 - Training loss: 0.0124
# [Pleural Effusion] Epoch 7 - Training loss: 0.0124
# [Pleural Effusion] Epoch 8 - Training loss: 0.0122
# [Pleural Effusion] Epoch 9 - Training loss: 0.0120
# [Pleural Effusion] Epoch 10 - Training loss: 0.0118
# [Pleural Effusion] Epoch 11 - Training loss: 0.0116
# [Pleural Effusion] Epoch 12 - Training loss: 0.0114
# [Pleural Effusion] Epoch 13 - Training loss: 0.0114
# [Pleural Effusion] Epoch 14 - Training loss: 0.0112
# [Pleural Effusion] Epoch 15 - Training loss: 0.0111
#  Model for Pleural Effusion saved to transformer_label_9_Pleural Effusion.pt
#
#  Running ASL grid search for label: Pleural Other
#
#  Grid search for label: Pleural Other
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.3851
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.3857
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.3858
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.3798
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.3877
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.3888
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.3814
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.3898
#  Best config for Pleural Other: gamma_pos=0.5, gamma_neg=6.0 with AP=0.3898
#  Training with gamma_pos=0.5, gamma_neg=6.0
# [Pleural Other] Epoch 1 - Training loss: 0.0358
# [Pleural Other] Epoch 2 - Training loss: 0.0337
# [Pleural Other] Epoch 3 - Training loss: 0.0332
# [Pleural Other] Epoch 4 - Training loss: 0.0330
# [Pleural Other] Epoch 5 - Training loss: 0.0331
# [Pleural Other] Epoch 6 - Training loss: 0.0328
# [Pleural Other] Epoch 7 - Training loss: 0.0326
# [Pleural Other] Epoch 8 - Training loss: 0.0325
# [Pleural Other] Epoch 9 - Training loss: 0.0323
# [Pleural Other] Epoch 10 - Training loss: 0.0324
# [Pleural Other] Epoch 11 - Training loss: 0.0322
# [Pleural Other] Epoch 12 - Training loss: 0.0322
# [Pleural Other] Epoch 13 - Training loss: 0.0320
# [Pleural Other] Epoch 14 - Training loss: 0.0321
# [Pleural Other] Epoch 15 - Training loss: 0.0317
#  Model for Pleural Other saved to transformer_label_10_Pleural Other.pt
#
#  Running ASL grid search for label: Fracture
#
#  Grid search for label: Fracture
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.2096
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.2159
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.1819
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.2024
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.2098
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.1967
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.1817
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.1876
#  Best config for Fracture: gamma_pos=0.0, gamma_neg=4.0 with AP=0.2159
#  Training with gamma_pos=0.0, gamma_neg=4.0
# [Fracture] Epoch 1 - Training loss: 0.0197
# [Fracture] Epoch 2 - Training loss: 0.0183
# [Fracture] Epoch 3 - Training loss: 0.0178
# [Fracture] Epoch 4 - Training loss: 0.0175
# [Fracture] Epoch 5 - Training loss: 0.0174
# [Fracture] Epoch 6 - Training loss: 0.0174
# [Fracture] Epoch 7 - Training loss: 0.0171
# [Fracture] Epoch 8 - Training loss: 0.0171
# [Fracture] Epoch 9 - Training loss: 0.0170
# [Fracture] Epoch 10 - Training loss: 0.0169
# [Fracture] Epoch 11 - Training loss: 0.0168
# [Fracture] Epoch 12 - Training loss: 0.0166
# [Fracture] Epoch 13 - Training loss: 0.0167
# [Fracture] Epoch 14 - Training loss: 0.0165
# [Fracture] Epoch 15 - Training loss: 0.0163
#  Model for Fracture saved to transformer_label_11_Fracture.pt
#
#  Running ASL grid search for label: Support Devices
#
#  Grid search for label: Support Devices
# → gamma_pos=0.0, gamma_neg=3.0
#     → AP=0.5055
# → gamma_pos=0.0, gamma_neg=4.0
#     → AP=0.5167
# → gamma_pos=0.0, gamma_neg=5.0
#     → AP=0.5240
# → gamma_pos=0.0, gamma_neg=6.0
#     → AP=0.5145
# → gamma_pos=0.5, gamma_neg=3.0
#     → AP=0.5247
# → gamma_pos=0.5, gamma_neg=4.0
#     → AP=0.5214
# → gamma_pos=0.5, gamma_neg=5.0
#     → AP=0.5107
# → gamma_pos=0.5, gamma_neg=6.0
#     → AP=0.5170
#  Best config for Support Devices: gamma_pos=0.5, gamma_neg=3.0 with AP=0.5247
#  Training with gamma_pos=0.5, gamma_neg=3.0
# [Support Devices] Epoch 1 - Training loss: 0.0515
# [Support Devices] Epoch 2 - Training loss: 0.0461
# [Support Devices] Epoch 3 - Training loss: 0.0457
# [Support Devices] Epoch 4 - Training loss: 0.0455
# [Support Devices] Epoch 5 - Training loss: 0.0448
# [Support Devices] Epoch 6 - Training loss: 0.0449
# [Support Devices] Epoch 7 - Training loss: 0.0444
# [Support Devices] Epoch 8 - Training loss: 0.0444
# [Support Devices] Epoch 9 - Training loss: 0.0443
# [Support Devices] Epoch 10 - Training loss: 0.0441
# [Support Devices] Epoch 11 - Training loss: 0.0438
# [Support Devices] Epoch 12 - Training loss: 0.0436
# [Support Devices] Epoch 13 - Training loss: 0.0434
# [Support Devices] Epoch 14 - Training loss: 0.0430
# [Support Devices] Epoch 15 - Training loss: 0.0427
#  Model for Support Devices saved to transformer_label_12_Support Devices.pt
#
#  All best gamma configs saved to best_gamma_config_per_label.csv

# %%
def evaluate_model(model, dataloader, device):
    model.eval()
    all_probs = []
    all_targets = []

    with torch.no_grad():
        for batch in dataloader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device).squeeze()  # shape: (batch_size,)

            logits = model(x).squeeze()  # shape: (batch_size,)
            probs = torch.sigmoid(logits)

            all_probs.extend(probs.cpu().numpy())
            all_targets.extend(y.cpu().numpy())

    try:
        auc = roc_auc_score(all_targets, all_probs)
    except ValueError:
        auc = float('nan')

    return auc

# %%
for i, label_name in enumerate(label_names):
    print(f"\n Testing model for: {label_name}")

    # 1. Prepare test data for the current label
    test_X, test_y = get_single_label_data(test_embeddings, test_labels, i)
    test_ds = SingleLabelDataset(test_X, test_y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # 2. Rebuild the model architecture and load saved weights
    model = TabTransformer(input_dim=1376, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)

    # 3. Evaluate on the test set
    test_auc = evaluate_model(model, test_loader, device)
    print(f"[{label_name}] Test AUC: {test_auc:.4f}")
# Out:
#  Testing model for: Enlarged Cardiomediastinum
# [Enlarged Cardiomediastinum] Test AUC: 0.8970
#
#  Testing model for: Cardiomegaly
# [Cardiomegaly] Test AUC: 0.9143
#
#  Testing model for: Lung Opacity
# [Lung Opacity] Test AUC: 0.9122
#
#  Testing model for: Lung Lesion
# [Lung Lesion] Test AUC: 0.9627
#
#  Testing model for: Edema
# [Edema] Test AUC: 0.8007
#
#  Testing model for: Consolidation
# [Consolidation] Test AUC: 0.7898
#
#  Testing model for: Pneumonia
# [Pneumonia] Test AUC: 0.8877
#
#  Testing model for: Atelectasis
# [Atelectasis] Test AUC: 0.8663
#
#  Testing model for: Pneumothorax
# [Pneumothorax] Test AUC: 0.9474
#
#  Testing model for: Pleural Effusion
# [Pleural Effusion] Test AUC: 0.9292
#
#  Testing model for: Pleural Other
# [Pleural Other] Test AUC: 0.8409
#
#  Testing model for: Fracture
# [Fracture] Test AUC: 0.9193
#
#  Testing model for: Support Devices
# [Support Devices] Test AUC: 0.9144

# %%
def safe_get(report, class_label, metric):
    """
    Safely extract a specific class or average metric.
    - For class_label as 0 or 1, try multiple key formats;
    - For average entries like 'macro avg', lookup directly.
    """
    if isinstance(class_label, (int, float)):
        keys_to_try = [class_label, str(class_label), f"{float(class_label):.1f}"]
    else:
        keys_to_try = [class_label]

    for key in keys_to_try:
        if key in report and metric in report[key]:
            return report[key][metric]
    return np.nan


def evaluate_full_report(model, dataloader, device):
    model.eval()
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for batch in dataloader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device)

            logits = model(x)
            probs = torch.sigmoid(logits)
            preds = (probs > 0.5).float()

            all_labels.extend(y.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    # Accuracy: how many predictions match the ground truth
    accuracy = (np.array(all_labels) == np.array(all_preds)).mean()

    return classification_report(all_labels, all_preds, digits=4, output_dict=True), accuracy


# Collect reports for all labels
report_dict = {}

for i, label_name in enumerate(label_names):
    print("=" * 30)
    print(f" Test Evaluation Report for: {label_name}")
    print("=" * 30)

    # 1. Load test data for current label
    test_X, test_y = get_single_label_data(test_embeddings, test_labels, i)
    test_ds = SingleLabelDataset(test_X, test_y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # 2. Load corresponding model
    model = TabTransformer(input_dim=1376, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)

    # 3. Get classification report and accuracy
    report, acc = evaluate_full_report(model, test_loader, device)

    report_dict[label_name] = {
        # Class 0
        'precision_0': safe_get(report, 0, 'precision'),
        'recall_0': safe_get(report, 0, 'recall'),
        'f1-score_0': safe_get(report, 0, 'f1-score'),

        # Class 1
        'precision_1': safe_get(report, 1, 'precision'),
        'recall_1': safe_get(report, 1, 'recall'),
        'f1-score_1': safe_get(report, 1, 'f1-score'),

        # Macro average
        'precision': safe_get(report, 'macro avg', 'precision'),
        'recall': safe_get(report, 'macro avg', 'recall'),
        'f1-score': safe_get(report, 'macro avg', 'f1-score'),
        'support': safe_get(report, 'macro avg', 'support'),

        # Accuracy
        'accuracy': acc
    }

# Save as DataFrame
df = pd.DataFrame(report_dict)
df.index.name = "Metric"
df = df.round(4)
df.to_csv("test_metrics_per_label.csv")
print("\n Saved report with accuracy to: test_metrics_per_label.csv")
# Out:
# ==============================
#  Test Evaluation Report for: Enlarged Cardiomediastinum
# ==============================
# ==============================
#  Test Evaluation Report for: Cardiomegaly
# ==============================
# ==============================
#  Test Evaluation Report for: Lung Opacity
# ==============================
# ==============================
#  Test Evaluation Report for: Lung Lesion
# ==============================
# ==============================
#  Test Evaluation Report for: Edema
# ==============================
# ==============================
#  Test Evaluation Report for: Consolidation
# ==============================
# ==============================
#  Test Evaluation Report for: Pneumonia
# ==============================
# ==============================
#  Test Evaluation Report for: Atelectasis
# ==============================
# ==============================
#  Test Evaluation Report for: Pneumothorax
# ==============================
# ==============================
#  Test Evaluation Report for: Pleural Effusion
# ==============================
# ==============================
#  Test Evaluation Report for: Pleural Other
# ==============================
# ==============================
#  Test Evaluation Report for: Fracture
# ==============================
# ==============================
#  Test Evaluation Report for: Support Devices
# ==============================
#
#  Saved report with accuracy to: test_metrics_per_label.csv

# %%
def evaluate_auc_ap(model, dataloader, device):
    model.eval()
    all_probs = []
    all_targets = []

    with torch.no_grad():
        for batch in dataloader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device).squeeze()

            logits = model(x).squeeze()
            probs = torch.sigmoid(logits)

            all_probs.extend(probs.cpu().numpy())
            all_targets.extend(y.cpu().numpy())

    try:
        auc = roc_auc_score(all_targets, all_probs)
    except ValueError:
        auc = float('nan')

    try:
        ap = average_precision_score(all_targets, all_probs)
    except ValueError:
        ap = float('nan')

    return auc, ap

#  Evaluate on Test Set

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for i, label_name in enumerate(label_names):
    print("=" * 40)
    print(f" Test Metrics for: {label_name}")
    print("=" * 40)

    # 1. Load test data
    test_X, test_y = get_single_label_data(test_embeddings, test_labels, i)
    test_ds = SingleLabelDataset(test_X, test_y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # 2. Load model
    model = TabTransformer(input_dim=1376, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)

    # 3. Evaluate
    auc, ap = evaluate_auc_ap(model, test_loader, device)
    print(f"AUC Score:              {auc:.4f}")
    print(f"Average Precision (AP): {ap:.4f}\n")
# Out:
# ========================================
#  Test Metrics for: Enlarged Cardiomediastinum
# ========================================
# AUC Score:              0.8970
# Average Precision (AP): 0.5722
#
# ========================================
#  Test Metrics for: Cardiomegaly
# ========================================
# AUC Score:              0.9143
# Average Precision (AP): 0.5774
#
# ========================================
#  Test Metrics for: Lung Opacity
# ========================================
# AUC Score:              0.9122
# Average Precision (AP): 0.3569
#
# ========================================
#  Test Metrics for: Lung Lesion
# ========================================
# AUC Score:              0.9627
# Average Precision (AP): 0.5361
#
# ========================================
#  Test Metrics for: Edema
# ========================================
# AUC Score:              0.8007
# Average Precision (AP): 0.1108
#
# ========================================
#  Test Metrics for: Consolidation
# ========================================
# AUC Score:              0.7898
# Average Precision (AP): 0.1460
#
# ========================================
#  Test Metrics for: Pneumonia
# ========================================
# AUC Score:              0.8877
# Average Precision (AP): 0.3584
#
# ========================================
#  Test Metrics for: Atelectasis
# ========================================
# AUC Score:              0.8663
# Average Precision (AP): 0.5630
#
# ========================================
#  Test Metrics for: Pneumothorax
# ========================================
# AUC Score:              0.9474
# Average Precision (AP): 0.6906
#
# ========================================
#  Test Metrics for: Pleural Effusion
# ========================================
# AUC Score:              0.9292
# Average Precision (AP): 0.2138
#
# ========================================
#  Test Metrics for: Pleural Other
# ========================================
# AUC Score:              0.8409
# Average Precision (AP): 0.3967
#
# ========================================
#  Test Metrics for: Fracture
# ========================================
# AUC Score:              0.9193
# Average Precision (AP): 0.3148
#
# ========================================
#  Test Metrics for: Support Devices
# ========================================
# AUC Score:              0.9144
# Average Precision (AP): 0.4138

# %%
#  Evaluate multi-label classification models on the test set
#  Strategy: Per-label evaluation by skipping NaNs individually

# Step 1: Predict each label individually, skipping NaNs
all_true = []
all_pred = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for i, label_name in enumerate(label_names):
    print(f"Evaluating label: {label_name}")

    # Select non-NaN samples for this label
    mask = ~np.isnan(test_labels[:, i])
    X = test_embeddings[mask]
    y = test_labels[mask, i]

    test_ds = SingleLabelDataset(X, y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # Load model
    model = TabTransformer(input_dim=1376, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)
    model.eval()

    preds = []
    true_vals = []

    with torch.no_grad():
        for batch in test_loader:
            x = batch["embedding"].to(device)
            y_batch = batch["lab"].to(device)

            logits = model(x)
            probs = torch.sigmoid(logits)
            preds.extend(probs.cpu().numpy())  # Use raw probabilities for PR-AUC
            true_vals.extend(y_batch.cpu().numpy())

    all_pred.append(np.array(preds).flatten())
    all_true.append(np.array(true_vals).flatten())

# Step 2: Compute metrics
micro_acc = accuracy_score(
    np.concatenate([t.round() for t in all_true]),
    np.concatenate([p > 0.5 for p in all_pred])
)
macro_acc = np.mean([
    accuracy_score(all_true[i].round(), (all_pred[i] > 0.5).astype(int)) for i in range(len(label_names))
])

# Step 3: Compute PR-AUC per label
pr_auc_per_label = []
for i in range(len(label_names)):
    if len(np.unique(all_true[i])) > 1:
        auc = average_precision_score(all_true[i], all_pred[i])
        pr_auc_per_label.append(auc)
    else:
        pr_auc_per_label.append(np.nan)  # Cannot compute AUC with one class only

# Step 4: Print results
print("\n Evaluation on Test Set using per-label skipping of NaNs:")
print(f"Micro Accuracy (label-wise overall):     {micro_acc:.4f}")
print(f"Macro Accuracy (avg per label):          {macro_acc:.4f}")

print("\n Per-Label PR-AUC (Precision-Recall AUC):")
for i, label_name in enumerate(label_names):
    auc = pr_auc_per_label[i]
    print(f"{label_name:<25} → PR-AUC: {auc:.4f}" if not np.isnan(auc) else f"{label_name:<25} → PR-AUC: N/A")

macro_pr_auc = np.nanmean(pr_auc_per_label)
print(f"\nMacro PR-AUC (avg across labels): {macro_pr_auc:.4f}")

print("\n Label-wise Distribution After Skipping NaNs Individually (per-label view):\n")

for i, label_name in enumerate(label_names):
    label_vals = test_labels[:, i]
    valid_mask = ~np.isnan(label_vals)
    label_clean = label_vals[valid_mask]

    count_0 = np.sum(label_clean == 0)
    count_1 = np.sum(label_clean == 1)
    print(f"{label_name:<25} → 0: {count_0:<5} | 1: {count_1:<5} | total: {len(label_clean):<5}")
# Out:
# Evaluating label: Enlarged Cardiomediastinum
# Evaluating label: Cardiomegaly
# Evaluating label: Lung Opacity
# Evaluating label: Lung Lesion
# Evaluating label: Edema
# Evaluating label: Consolidation
# Evaluating label: Pneumonia
# Evaluating label: Atelectasis
# Evaluating label: Pneumothorax
# Evaluating label: Pleural Effusion
# Evaluating label: Pleural Other
# Evaluating label: Fracture
# Evaluating label: Support Devices
#
#  Evaluation on Test Set using per-label skipping of NaNs:
# Micro Accuracy (label-wise overall):     0.8907
# Macro Accuracy (avg per label):          0.8933
#
#  Per-Label PR-AUC (Precision-Recall AUC):
# Enlarged Cardiomediastinum → PR-AUC: 0.5722
# Cardiomegaly              → PR-AUC: 0.5774
# Lung Opacity              → PR-AUC: 0.3569
# Lung Lesion               → PR-AUC: 0.5361
# Edema                     → PR-AUC: 0.1108
# Consolidation             → PR-AUC: 0.1460
# Pneumonia                 → PR-AUC: 0.3584
# Atelectasis               → PR-AUC: 0.5630
# Pneumothorax              → PR-AUC: 0.6906
# Pleural Effusion          → PR-AUC: 0.2138
# Pleural Other             → PR-AUC: 0.3967
# Fracture                  → PR-AUC: 0.3148
# Support Devices           → PR-AUC: 0.4138
#
# Macro PR-AUC (avg across labels): 0.4039
#
#  Label-wise Distribution After Skipping NaNs Individually (per-label view):
#
# Enlarged Cardiomediastinum → 0: 3046  | 1: 446   | total: 3492
# Cardiomegaly              → 0: 3202  | 1: 400   | total: 3602
# Lung Opacity              → 0: 3167  | 1: 75    | total: 3242
# Lung Lesion               → 0: 3332  | 1: 123   | total: 3455
# Edema                     → 0: 3106  | 1: 70    | total: 3176
# Consolidation             → 0: 3047  | 1: 82    | total: 3129
# Pneumonia                 → 0: 3057  | 1: 120   | total: 3177
# Atelectasis               → 0: 3068  | 1: 576   | total: 3644
# Pneumothorax              → 0: 3295  | 1: 393   | total: 3688
# Pleural Effusion          → 0: 3038  | 1: 44    | total: 3082
# Pleural Other             → 0: 3310  | 1: 226   | total: 3536
# Fracture                  → 0: 3341  | 1: 55    | total: 3396
# Support Devices           → 0: 3067  | 1: 201   | total: 3268
