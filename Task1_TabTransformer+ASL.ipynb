# %%
# Standard Libraries
import os
import random
from typing import Dict, List

# Third-Party Libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# PyTorch 
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# Evaluation Metrics (sklearn) 
from sklearn.metrics import (
    accuracy_score,
    average_precision_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
label_names =  [
    "Enlarged Cardiomediastinum", "Cardiomegaly", "Lung Opacity", "Lung Lesion",
    "Edema", "Consolidation", "Pneumonia", "Atelectasis",
    "Pneumothorax", "Pleural Effusion", "Pleural Other", "Fracture", "Support Devices"
]

data = np.load("mimic_embed_data.npz")
train_embeddings = data["train_embeddings"]
train_labels = data["train_labels"]
valid_embeddings = data["valid_embeddings"]
valid_labels = data["valid_labels"]
test_embeddings = data["test_embeddings"]
test_labels = data["test_labels"]

# %%
class SingleLabelDataset(Dataset):
    def __init__(self, embeddings, labels):
        self.embeddings = torch.tensor(embeddings, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.float32)

    def __len__(self):
        return len(self.embeddings)

    def __getitem__(self, idx):
        return {
            "embedding": self.embeddings[idx],
            "lab": self.labels[idx].unsqueeze(0)  #  shape: (1,)
        }

# %%
class TabTransformer(nn.Module):
    def __init__(self, input_dim=1376, hidden_dim=128, output_dim=1, nhead=8, nlayers=4, dropout=0.1):
        super(TabTransformer, self).__init__()

        self.input_proj = nn.Linear(input_dim, hidden_dim)
        self.norm = nn.LayerNorm(hidden_dim)

        encoder_layer = self._build_encoder_layer(hidden_dim, nhead, dropout)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=nlayers)

        self.classifier = nn.Linear(hidden_dim, output_dim)

    def _build_encoder_layer(self, hidden_dim, nhead, dropout):
        return nn.TransformerEncoderLayer(
            d_model=hidden_dim,
            nhead=nhead,
            dim_feedforward=hidden_dim * 8,
            dropout=dropout,
            activation='gelu',
            batch_first=True
        )

    def forward(self, x):
        x = self.input_proj(x)
        x = self.norm(x)
        x = x.unsqueeze(1)
        x = self.encoder(x)
        x = x.squeeze(1)
        return self.classifier(x)

# %%
class MaskedAsymmetricLoss(nn.Module):
    def __init__(self, gamma_pos=0, gamma_neg=4):
        super().__init__()
        self.gamma_pos = gamma_pos
        self.gamma_neg = gamma_neg

    def forward(self, logits, labels, mask):
        probs = torch.sigmoid(logits)
        # Positive loss
        pos_loss = labels * torch.pow(1 - probs, self.gamma_pos) * torch.log(probs + 1e-8)
        # Negative loss
        neg_loss = (1 - labels) * torch.pow(probs, self.gamma_neg) * torch.log(1 - probs + 1e-8)
        # Combined loss
        loss = - (pos_loss + neg_loss)
        # Apply mask
        return (loss * mask).sum() / mask.sum()

# %%
def train_single_label_model(train_loader, val_loader, label_name, save_path):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model = TabTransformer().to(device)
    criterion = MaskedAsymmetricLoss(gamma_pos=0, gamma_neg=4)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

    for epoch in range(15):
        model.train()
        total_loss = 0

        for batch in train_loader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device)
            mask = torch.ones_like(y)

            logits = model(x)
            loss = criterion(logits, y, mask)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"[{label_name}] Epoch {epoch+1} - Training loss: {avg_loss:.4f}")

    torch.save(model.state_dict(), save_path)
    print(f"Model for {label_name} saved to {save_path}")

    return model

# %%
def get_single_label_data(embeddings, labels, label_idx):
    mask = ~np.isnan(labels[:, label_idx])
    return embeddings[mask], labels[mask, label_idx]

for i, label_name in enumerate(label_names):
    print(f"\n Training model for: {label_name}")

    train_X, train_y = get_single_label_data(train_embeddings, train_labels, i)
    val_X, val_y = get_single_label_data(valid_embeddings, valid_labels, i)

    train_ds = SingleLabelDataset(train_X, train_y)
    val_ds = SingleLabelDataset(val_X, val_y)

    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=32, shuffle=False)

    model_path = f"transformer_label_{i}_{label_name}.pt"
    train_single_label_model(train_loader, val_loader, label_name, model_path)
# Out:
#  Training model for: Enlarged Cardiomediastinum
# [Enlarged Cardiomediastinum] Epoch 1 - Training loss: 0.0900
# [Enlarged Cardiomediastinum] Epoch 2 - Training loss: 0.0863
# [Enlarged Cardiomediastinum] Epoch 3 - Training loss: 0.0857
# [Enlarged Cardiomediastinum] Epoch 4 - Training loss: 0.0850
# [Enlarged Cardiomediastinum] Epoch 5 - Training loss: 0.0846
# [Enlarged Cardiomediastinum] Epoch 6 - Training loss: 0.0842
# [Enlarged Cardiomediastinum] Epoch 7 - Training loss: 0.0841
# [Enlarged Cardiomediastinum] Epoch 8 - Training loss: 0.0838
# [Enlarged Cardiomediastinum] Epoch 9 - Training loss: 0.0837
# [Enlarged Cardiomediastinum] Epoch 10 - Training loss: 0.0833
# [Enlarged Cardiomediastinum] Epoch 11 - Training loss: 0.0831
# [Enlarged Cardiomediastinum] Epoch 12 - Training loss: 0.0828
# [Enlarged Cardiomediastinum] Epoch 13 - Training loss: 0.0824
# [Enlarged Cardiomediastinum] Epoch 14 - Training loss: 0.0823
# [Enlarged Cardiomediastinum] Epoch 15 - Training loss: 0.0819
# Model for Enlarged Cardiomediastinum saved to transformer_label_0_Enlarged Cardiomediastinum.pt
#
#  Training model for: Cardiomegaly
# [Cardiomegaly] Epoch 1 - Training loss: 0.0835
# [Cardiomegaly] Epoch 2 - Training loss: 0.0788
# [Cardiomegaly] Epoch 3 - Training loss: 0.0781
# [Cardiomegaly] Epoch 4 - Training loss: 0.0775
# [Cardiomegaly] Epoch 5 - Training loss: 0.0772
# [Cardiomegaly] Epoch 6 - Training loss: 0.0771
# [Cardiomegaly] Epoch 7 - Training loss: 0.0766
# [Cardiomegaly] Epoch 8 - Training loss: 0.0765
# [Cardiomegaly] Epoch 9 - Training loss: 0.0762
# [Cardiomegaly] Epoch 10 - Training loss: 0.0757
# [Cardiomegaly] Epoch 11 - Training loss: 0.0758
# [Cardiomegaly] Epoch 12 - Training loss: 0.0755
# [Cardiomegaly] Epoch 13 - Training loss: 0.0751
# [Cardiomegaly] Epoch 14 - Training loss: 0.0752
# [Cardiomegaly] Epoch 15 - Training loss: 0.0749
# Model for Cardiomegaly saved to transformer_label_1_Cardiomegaly.pt
#
#  Training model for: Lung Opacity
# [Lung Opacity] Epoch 1 - Training loss: 0.0262
# [Lung Opacity] Epoch 2 - Training loss: 0.0246
# [Lung Opacity] Epoch 3 - Training loss: 0.0242
# [Lung Opacity] Epoch 4 - Training loss: 0.0242
# [Lung Opacity] Epoch 5 - Training loss: 0.0239
# [Lung Opacity] Epoch 6 - Training loss: 0.0237
# [Lung Opacity] Epoch 7 - Training loss: 0.0236
# [Lung Opacity] Epoch 8 - Training loss: 0.0234
# [Lung Opacity] Epoch 9 - Training loss: 0.0234
# [Lung Opacity] Epoch 10 - Training loss: 0.0233
# [Lung Opacity] Epoch 11 - Training loss: 0.0231
# [Lung Opacity] Epoch 12 - Training loss: 0.0231
# [Lung Opacity] Epoch 13 - Training loss: 0.0229
# [Lung Opacity] Epoch 14 - Training loss: 0.0229
# [Lung Opacity] Epoch 15 - Training loss: 0.0227
# Model for Lung Opacity saved to transformer_label_2_Lung Opacity.pt
#
#  Training model for: Lung Lesion
# [Lung Lesion] Epoch 1 - Training loss: 0.0342
# [Lung Lesion] Epoch 2 - Training loss: 0.0281
# [Lung Lesion] Epoch 3 - Training loss: 0.0276
# [Lung Lesion] Epoch 4 - Training loss: 0.0271
# [Lung Lesion] Epoch 5 - Training loss: 0.0271
# [Lung Lesion] Epoch 6 - Training loss: 0.0267
# [Lung Lesion] Epoch 7 - Training loss: 0.0266
# [Lung Lesion] Epoch 8 - Training loss: 0.0266
# [Lung Lesion] Epoch 9 - Training loss: 0.0263
# [Lung Lesion] Epoch 10 - Training loss: 0.0265
# [Lung Lesion] Epoch 11 - Training loss: 0.0263
# [Lung Lesion] Epoch 12 - Training loss: 0.0260
# [Lung Lesion] Epoch 13 - Training loss: 0.0257
# [Lung Lesion] Epoch 14 - Training loss: 0.0256
# [Lung Lesion] Epoch 15 - Training loss: 0.0254
# Model for Lung Lesion saved to transformer_label_3_Lung Lesion.pt
#
#  Training model for: Edema
# [Edema] Epoch 1 - Training loss: 0.0259
# [Edema] Epoch 2 - Training loss: 0.0249
# [Edema] Epoch 3 - Training loss: 0.0247
# [Edema] Epoch 4 - Training loss: 0.0243
# [Edema] Epoch 5 - Training loss: 0.0243
# [Edema] Epoch 6 - Training loss: 0.0241
# [Edema] Epoch 7 - Training loss: 0.0240
# [Edema] Epoch 8 - Training loss: 0.0239
# [Edema] Epoch 9 - Training loss: 0.0239
# [Edema] Epoch 10 - Training loss: 0.0238
# [Edema] Epoch 11 - Training loss: 0.0236
# [Edema] Epoch 12 - Training loss: 0.0236
# [Edema] Epoch 13 - Training loss: 0.0234
# [Edema] Epoch 14 - Training loss: 0.0234
# [Edema] Epoch 15 - Training loss: 0.0232
# Model for Edema saved to transformer_label_4_Edema.pt
#
#  Training model for: Consolidation
# [Consolidation] Epoch 1 - Training loss: 0.0395
# [Consolidation] Epoch 2 - Training loss: 0.0363
# [Consolidation] Epoch 3 - Training loss: 0.0358
# [Consolidation] Epoch 4 - Training loss: 0.0354
# [Consolidation] Epoch 5 - Training loss: 0.0351
# [Consolidation] Epoch 6 - Training loss: 0.0348
# [Consolidation] Epoch 7 - Training loss: 0.0347
# [Consolidation] Epoch 8 - Training loss: 0.0345
# [Consolidation] Epoch 9 - Training loss: 0.0345
# [Consolidation] Epoch 10 - Training loss: 0.0341
# [Consolidation] Epoch 11 - Training loss: 0.0343
# [Consolidation] Epoch 12 - Training loss: 0.0340
# [Consolidation] Epoch 13 - Training loss: 0.0336
# [Consolidation] Epoch 14 - Training loss: 0.0335
# [Consolidation] Epoch 15 - Training loss: 0.0335
# Model for Consolidation saved to transformer_label_5_Consolidation.pt
#
#  Training model for: Pneumonia
# [Pneumonia] Epoch 1 - Training loss: 0.0427
# [Pneumonia] Epoch 2 - Training loss: 0.0404
# [Pneumonia] Epoch 3 - Training loss: 0.0399
# [Pneumonia] Epoch 4 - Training loss: 0.0395
# [Pneumonia] Epoch 5 - Training loss: 0.0396
# [Pneumonia] Epoch 6 - Training loss: 0.0392
# [Pneumonia] Epoch 7 - Training loss: 0.0391
# [Pneumonia] Epoch 8 - Training loss: 0.0389
# [Pneumonia] Epoch 9 - Training loss: 0.0388
# [Pneumonia] Epoch 10 - Training loss: 0.0387
# [Pneumonia] Epoch 11 - Training loss: 0.0386
# [Pneumonia] Epoch 12 - Training loss: 0.0384
# [Pneumonia] Epoch 13 - Training loss: 0.0386
# [Pneumonia] Epoch 14 - Training loss: 0.0381
# [Pneumonia] Epoch 15 - Training loss: 0.0379
# Model for Pneumonia saved to transformer_label_6_Pneumonia.pt
#
#  Training model for: Atelectasis
# [Atelectasis] Epoch 1 - Training loss: 0.1138
# [Atelectasis] Epoch 2 - Training loss: 0.1096
# [Atelectasis] Epoch 3 - Training loss: 0.1086
# [Atelectasis] Epoch 4 - Training loss: 0.1079
# [Atelectasis] Epoch 5 - Training loss: 0.1075
# [Atelectasis] Epoch 6 - Training loss: 0.1074
# [Atelectasis] Epoch 7 - Training loss: 0.1068
# [Atelectasis] Epoch 8 - Training loss: 0.1066
# [Atelectasis] Epoch 9 - Training loss: 0.1064
# [Atelectasis] Epoch 10 - Training loss: 0.1059
# [Atelectasis] Epoch 11 - Training loss: 0.1059
# [Atelectasis] Epoch 12 - Training loss: 0.1054
# [Atelectasis] Epoch 13 - Training loss: 0.1052
# [Atelectasis] Epoch 14 - Training loss: 0.1050
# [Atelectasis] Epoch 15 - Training loss: 0.1047
# Model for Atelectasis saved to transformer_label_7_Atelectasis.pt
#
#  Training model for: Pneumothorax
# [Pneumothorax] Epoch 1 - Training loss: 0.0699
# [Pneumothorax] Epoch 2 - Training loss: 0.0649
# [Pneumothorax] Epoch 3 - Training loss: 0.0642
# [Pneumothorax] Epoch 4 - Training loss: 0.0635
# [Pneumothorax] Epoch 5 - Training loss: 0.0629
# [Pneumothorax] Epoch 6 - Training loss: 0.0630
# [Pneumothorax] Epoch 7 - Training loss: 0.0625
# [Pneumothorax] Epoch 8 - Training loss: 0.0625
# [Pneumothorax] Epoch 9 - Training loss: 0.0620
# [Pneumothorax] Epoch 10 - Training loss: 0.0616
# [Pneumothorax] Epoch 11 - Training loss: 0.0613
# [Pneumothorax] Epoch 12 - Training loss: 0.0610
# [Pneumothorax] Epoch 13 - Training loss: 0.0608
# [Pneumothorax] Epoch 14 - Training loss: 0.0603
# [Pneumothorax] Epoch 15 - Training loss: 0.0601
# Model for Pneumothorax saved to transformer_label_8_Pneumothorax.pt
#
#  Training model for: Pleural Effusion
# [Pleural Effusion] Epoch 1 - Training loss: 0.0176
# [Pleural Effusion] Epoch 2 - Training loss: 0.0163
# [Pleural Effusion] Epoch 3 - Training loss: 0.0161
# [Pleural Effusion] Epoch 4 - Training loss: 0.0157
# [Pleural Effusion] Epoch 5 - Training loss: 0.0156
# [Pleural Effusion] Epoch 6 - Training loss: 0.0155
# [Pleural Effusion] Epoch 7 - Training loss: 0.0153
# [Pleural Effusion] Epoch 8 - Training loss: 0.0151
# [Pleural Effusion] Epoch 9 - Training loss: 0.0148
# [Pleural Effusion] Epoch 10 - Training loss: 0.0148
# [Pleural Effusion] Epoch 11 - Training loss: 0.0146
# [Pleural Effusion] Epoch 12 - Training loss: 0.0146
# [Pleural Effusion] Epoch 13 - Training loss: 0.0142
# [Pleural Effusion] Epoch 14 - Training loss: 0.0142
# [Pleural Effusion] Epoch 15 - Training loss: 0.0141
# Model for Pleural Effusion saved to transformer_label_9_Pleural Effusion.pt
#
#  Training model for: Pleural Other
# [Pleural Other] Epoch 1 - Training loss: 0.0617
# [Pleural Other] Epoch 2 - Training loss: 0.0589
# [Pleural Other] Epoch 3 - Training loss: 0.0584
# [Pleural Other] Epoch 4 - Training loss: 0.0574
# [Pleural Other] Epoch 5 - Training loss: 0.0575
# [Pleural Other] Epoch 6 - Training loss: 0.0569
# [Pleural Other] Epoch 7 - Training loss: 0.0570
# [Pleural Other] Epoch 8 - Training loss: 0.0567
# [Pleural Other] Epoch 9 - Training loss: 0.0566
# [Pleural Other] Epoch 10 - Training loss: 0.0563
# [Pleural Other] Epoch 11 - Training loss: 0.0563
# [Pleural Other] Epoch 12 - Training loss: 0.0563
# [Pleural Other] Epoch 13 - Training loss: 0.0559
# [Pleural Other] Epoch 14 - Training loss: 0.0558
# [Pleural Other] Epoch 15 - Training loss: 0.0557
# Model for Pleural Other saved to transformer_label_10_Pleural Other.pt
#
#  Training model for: Fracture
# [Fracture] Epoch 1 - Training loss: 0.0208
# [Fracture] Epoch 2 - Training loss: 0.0184
# [Fracture] Epoch 3 - Training loss: 0.0181
# [Fracture] Epoch 4 - Training loss: 0.0180
# [Fracture] Epoch 5 - Training loss: 0.0176
# [Fracture] Epoch 6 - Training loss: 0.0174
# [Fracture] Epoch 7 - Training loss: 0.0172
# [Fracture] Epoch 8 - Training loss: 0.0172
# [Fracture] Epoch 9 - Training loss: 0.0172
# [Fracture] Epoch 10 - Training loss: 0.0171
# [Fracture] Epoch 11 - Training loss: 0.0171
# [Fracture] Epoch 12 - Training loss: 0.0169
# [Fracture] Epoch 13 - Training loss: 0.0167
# [Fracture] Epoch 14 - Training loss: 0.0166
# [Fracture] Epoch 15 - Training loss: 0.0165
# Model for Fracture saved to transformer_label_11_Fracture.pt
#
#  Training model for: Support Devices
# [Support Devices] Epoch 1 - Training loss: 0.0516
# [Support Devices] Epoch 2 - Training loss: 0.0494
# [Support Devices] Epoch 3 - Training loss: 0.0488
# [Support Devices] Epoch 4 - Training loss: 0.0483
# [Support Devices] Epoch 5 - Training loss: 0.0482
# [Support Devices] Epoch 6 - Training loss: 0.0479
# [Support Devices] Epoch 7 - Training loss: 0.0478
# [Support Devices] Epoch 8 - Training loss: 0.0475
# [Support Devices] Epoch 9 - Training loss: 0.0474
# [Support Devices] Epoch 10 - Training loss: 0.0471
# [Support Devices] Epoch 11 - Training loss: 0.0470
# [Support Devices] Epoch 12 - Training loss: 0.0468
# [Support Devices] Epoch 13 - Training loss: 0.0465
# [Support Devices] Epoch 14 - Training loss: 0.0463
# [Support Devices] Epoch 15 - Training loss: 0.0460
# Model for Support Devices saved to transformer_label_12_Support Devices.pt

# %%
def evaluate_model(model, dataloader, device):
    model.eval()
    all_probs = []
    all_targets = []

    with torch.no_grad():
        for batch in dataloader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device).squeeze()  # shape: (batch_size,)

            logits = model(x).squeeze()  # shape: (batch_size,)
            probs = torch.sigmoid(logits)

            all_probs.extend(probs.cpu().numpy())
            all_targets.extend(y.cpu().numpy())

    try:
        auc = roc_auc_score(all_targets, all_probs)
    except ValueError:
        auc = float('nan')

    return auc

# %%
for i, label_name in enumerate(label_names):
    print(f"\n Testing model for: {label_name}")

    # 1. Prepare test data for the current label
    test_X, test_y = get_single_label_data(test_embeddings, test_labels, i)
    test_ds = SingleLabelDataset(test_X, test_y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # 2. Rebuild the model architecture and load saved weights
    model = TabTransformer(input_dim=1376, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)

    # 3. Evaluate on the test set
    test_auc = evaluate_model(model, test_loader, device)
    print(f"[{label_name}] Test AUC: {test_auc:.4f}")
# Out:
#  Testing model for: Enlarged Cardiomediastinum
# [Enlarged Cardiomediastinum] Test AUC: 0.8989
#
#  Testing model for: Cardiomegaly
# [Cardiomegaly] Test AUC: 0.9129
#
#  Testing model for: Lung Opacity
# [Lung Opacity] Test AUC: 0.9049
#
#  Testing model for: Lung Lesion
# [Lung Lesion] Test AUC: 0.9619
#
#  Testing model for: Edema
# [Edema] Test AUC: 0.8091
#
#  Testing model for: Consolidation
# [Consolidation] Test AUC: 0.7840
#
#  Testing model for: Pneumonia
# [Pneumonia] Test AUC: 0.8895
#
#  Testing model for: Atelectasis
# [Atelectasis] Test AUC: 0.8659
#
#  Testing model for: Pneumothorax
# [Pneumothorax] Test AUC: 0.9463
#
#  Testing model for: Pleural Effusion
# [Pleural Effusion] Test AUC: 0.9400
#
#  Testing model for: Pleural Other
# [Pleural Other] Test AUC: 0.8396
#
#  Testing model for: Fracture
# [Fracture] Test AUC: 0.9080
#
#  Testing model for: Support Devices
# [Support Devices] Test AUC: 0.9170

# %%
def safe_get(report, class_label, metric):
    """
    Safely extract a specific class or average metric.
    - For class_label as 0 or 1, try multiple key formats;
    - For average entries like 'macro avg', lookup directly.
    """
    if isinstance(class_label, (int, float)):
        keys_to_try = [class_label, str(class_label), f"{float(class_label):.1f}"]
    else:
        keys_to_try = [class_label]

    for key in keys_to_try:
        if key in report and metric in report[key]:
            return report[key][metric]
    return np.nan


def evaluate_full_report(model, dataloader, device):
    model.eval()
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for batch in dataloader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device)

            logits = model(x)
            probs = torch.sigmoid(logits)
            preds = (probs > 0.5).float()

            all_labels.extend(y.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    # Accuracy: how many predictions match the ground truth
    accuracy = (np.array(all_labels) == np.array(all_preds)).mean()

    return classification_report(all_labels, all_preds, digits=4, output_dict=True), accuracy


# === Collect reports for all labels ===
report_dict = {}

for i, label_name in enumerate(label_names):
    print("=" * 30)
    print(f" Test Evaluation Report for: {label_name}")
    print("=" * 30)

    # 1. Load test data for current label
    test_X, test_y = get_single_label_data(test_embeddings, test_labels, i)
    test_ds = SingleLabelDataset(test_X, test_y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # 2. Load corresponding model
    model = TabTransformer(input_dim=1376, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)

    # 3. Get classification report and accuracy
    report, acc = evaluate_full_report(model, test_loader, device)

    report_dict[label_name] = {
        # Class 0
        'precision_0': safe_get(report, 0, 'precision'),
        'recall_0': safe_get(report, 0, 'recall'),
        'f1-score_0': safe_get(report, 0, 'f1-score'),

        # Class 1
        'precision_1': safe_get(report, 1, 'precision'),
        'recall_1': safe_get(report, 1, 'recall'),
        'f1-score_1': safe_get(report, 1, 'f1-score'),

        # Macro average
        'precision': safe_get(report, 'macro avg', 'precision'),
        'recall': safe_get(report, 'macro avg', 'recall'),
        'f1-score': safe_get(report, 'macro avg', 'f1-score'),
        'support': safe_get(report, 'macro avg', 'support'),

        # Accuracy
        'accuracy': acc
    }

# === Save as DataFrame ===
df = pd.DataFrame(report_dict)
df.index.name = "Metric"
df = df.round(4)
df.to_csv("test_metrics_per_label.csv")
print("\n Saved report with accuracy to: test_metrics_per_label.csv")
# Out:
# ==============================
#  Test Evaluation Report for: Enlarged Cardiomediastinum
# ==============================
# ==============================
#  Test Evaluation Report for: Cardiomegaly
# ==============================
# ==============================
#  Test Evaluation Report for: Lung Opacity
# ==============================
# ==============================
#  Test Evaluation Report for: Lung Lesion
# ==============================
# ==============================
#  Test Evaluation Report for: Edema
# ==============================
# ==============================
#  Test Evaluation Report for: Consolidation
# ==============================
# ==============================
#  Test Evaluation Report for: Pneumonia
# ==============================
# ==============================
#  Test Evaluation Report for: Atelectasis
# ==============================
# ==============================
#  Test Evaluation Report for: Pneumothorax
# ==============================
# ==============================
#  Test Evaluation Report for: Pleural Effusion
# ==============================
# ==============================
#  Test Evaluation Report for: Pleural Other
# ==============================
# ==============================
#  Test Evaluation Report for: Fracture
# ==============================
# ==============================
#  Test Evaluation Report for: Support Devices
# ==============================
#
#  Saved report with accuracy to: test_metrics_per_label.csv

# %%
def evaluate_auc_ap(model, dataloader, device):
    model.eval()
    all_probs = []
    all_targets = []

    with torch.no_grad():
        for batch in dataloader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device).squeeze()

            logits = model(x).squeeze()
            probs = torch.sigmoid(logits)

            all_probs.extend(probs.cpu().numpy())
            all_targets.extend(y.cpu().numpy())

    try:
        auc = roc_auc_score(all_targets, all_probs)
    except ValueError:
        auc = float('nan')

    try:
        ap = average_precision_score(all_targets, all_probs)
    except ValueError:
        ap = float('nan')

    return auc, ap

#  Evaluate on Test Set

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for i, label_name in enumerate(label_names):
    print("=" * 40)
    print(f" Test Metrics for: {label_name}")
    print("=" * 40)

    # 1. Load test data
    test_X, test_y = get_single_label_data(test_embeddings, test_labels, i)
    test_ds = SingleLabelDataset(test_X, test_y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # 2. Load model
    model = TabTransformer(input_dim=1376, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)

    # 3. Evaluate
    auc, ap = evaluate_auc_ap(model, test_loader, device)
    print(f"AUC Score:              {auc:.4f}")
    print(f"Average Precision (AP): {ap:.4f}\n")
# Out:
# ========================================
#  Test Metrics for: Enlarged Cardiomediastinum
# ========================================
# AUC Score:              0.8989
# Average Precision (AP): 0.5724
#
# ========================================
#  Test Metrics for: Cardiomegaly
# ========================================
# AUC Score:              0.9129
# Average Precision (AP): 0.5699
#
# ========================================
#  Test Metrics for: Lung Opacity
# ========================================
# AUC Score:              0.9049
# Average Precision (AP): 0.3583
#
# ========================================
#  Test Metrics for: Lung Lesion
# ========================================
# AUC Score:              0.9619
# Average Precision (AP): 0.4983
#
# ========================================
#  Test Metrics for: Edema
# ========================================
# AUC Score:              0.8091
# Average Precision (AP): 0.1095
#
# ========================================
#  Test Metrics for: Consolidation
# ========================================
# AUC Score:              0.7840
# Average Precision (AP): 0.1399
#
# ========================================
#  Test Metrics for: Pneumonia
# ========================================
# AUC Score:              0.8895
# Average Precision (AP): 0.3571
#
# ========================================
#  Test Metrics for: Atelectasis
# ========================================
# AUC Score:              0.8659
# Average Precision (AP): 0.5641
#
# ========================================
#  Test Metrics for: Pneumothorax
# ========================================
# AUC Score:              0.9463
# Average Precision (AP): 0.6899
#
# ========================================
#  Test Metrics for: Pleural Effusion
# ========================================
# AUC Score:              0.9400
# Average Precision (AP): 0.2084
#
# ========================================
#  Test Metrics for: Pleural Other
# ========================================
# AUC Score:              0.8396
# Average Precision (AP): 0.4034
#
# ========================================
#  Test Metrics for: Fracture
# ========================================
# AUC Score:              0.9080
# Average Precision (AP): 0.3022
#
# ========================================
#  Test Metrics for: Support Devices
# ========================================
# AUC Score:              0.9170
# Average Precision (AP): 0.4252

# %%
#  Evaluate multi-label classification models on the test set
#  Strategy: Per-label evaluation by skipping NaNs individually

# Step 1: Predict each label individually, skipping NaNs
all_true = []
all_pred = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for i, label_name in enumerate(label_names):
    print(f"Evaluating label: {label_name}")

    # Select non-NaN samples for this label
    mask = ~np.isnan(test_labels[:, i])
    X = test_embeddings[mask]
    y = test_labels[mask, i]

    test_ds = SingleLabelDataset(X, y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # Load model
    model = TabTransformer(input_dim=1376, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)
    model.eval()

    preds = []
    true_vals = []

    with torch.no_grad():
        for batch in test_loader:
            x = batch["embedding"].to(device)
            y_batch = batch["lab"].to(device)

            logits = model(x)
            probs = torch.sigmoid(logits)
            preds.extend(probs.cpu().numpy())  # Use raw probabilities for PR-AUC
            true_vals.extend(y_batch.cpu().numpy())

    all_pred.append(np.array(preds).flatten())
    all_true.append(np.array(true_vals).flatten())

# Step 2: Compute metrics
micro_acc = accuracy_score(
    np.concatenate([t.round() for t in all_true]),
    np.concatenate([p > 0.5 for p in all_pred])
)
macro_acc = np.mean([
    accuracy_score(all_true[i].round(), (all_pred[i] > 0.5).astype(int)) for i in range(len(label_names))
])

# Step 3: Compute PR-AUC per label
pr_auc_per_label = []
for i in range(len(label_names)):
    if len(np.unique(all_true[i])) > 1:
        auc = average_precision_score(all_true[i], all_pred[i])
        pr_auc_per_label.append(auc)
    else:
        pr_auc_per_label.append(np.nan)  # Cannot compute AUC with one class only

# Step 4: Print results
print("\n Evaluation on Test Set using per-label skipping of NaNs:")
print(f"Micro Accuracy (label-wise overall):     {micro_acc:.4f}")
print(f"Macro Accuracy (avg per label):          {macro_acc:.4f}")

print("\n Per-Label PR-AUC (Precision-Recall AUC):")
for i, label_name in enumerate(label_names):
    auc = pr_auc_per_label[i]
    print(f"{label_name:<25} → PR-AUC: {auc:.4f}" if not np.isnan(auc) else f"{label_name:<25} → PR-AUC: N/A")

macro_pr_auc = np.nanmean(pr_auc_per_label)
print(f"\nMacro PR-AUC (avg across labels): {macro_pr_auc:.4f}")

print("\n Label-wise Distribution After Skipping NaNs Individually (per-label view):\n")

for i, label_name in enumerate(label_names):
    label_vals = test_labels[:, i]
    valid_mask = ~np.isnan(label_vals)
    label_clean = label_vals[valid_mask]

    count_0 = np.sum(label_clean == 0)
    count_1 = np.sum(label_clean == 1)
    print(f"{label_name:<25} → 0: {count_0:<5} | 1: {count_1:<5} | total: {len(label_clean):<5}")
# Out:
# Evaluating label: Enlarged Cardiomediastinum
# Evaluating label: Cardiomegaly
# Evaluating label: Lung Opacity
# Evaluating label: Lung Lesion
# Evaluating label: Edema
# Evaluating label: Consolidation
# Evaluating label: Pneumonia
# Evaluating label: Atelectasis
# Evaluating label: Pneumothorax
# Evaluating label: Pleural Effusion
# Evaluating label: Pleural Other
# Evaluating label: Fracture
# Evaluating label: Support Devices
#
#  Evaluation on Test Set using per-label skipping of NaNs:
# Micro Accuracy (label-wise overall):     0.9199
# Macro Accuracy (avg per label):          0.9219
#
#  Per-Label PR-AUC (Precision-Recall AUC):
# Enlarged Cardiomediastinum → PR-AUC: 0.5724
# Cardiomegaly              → PR-AUC: 0.5699
# Lung Opacity              → PR-AUC: 0.3583
# Lung Lesion               → PR-AUC: 0.4983
# Edema                     → PR-AUC: 0.1095
# Consolidation             → PR-AUC: 0.1399
# Pneumonia                 → PR-AUC: 0.3571
# Atelectasis               → PR-AUC: 0.5641
# Pneumothorax              → PR-AUC: 0.6899
# Pleural Effusion          → PR-AUC: 0.2084
# Pleural Other             → PR-AUC: 0.4034
# Fracture                  → PR-AUC: 0.3022
# Support Devices           → PR-AUC: 0.4252
#
# Macro PR-AUC (avg across labels): 0.3999
#
#  Label-wise Distribution After Skipping NaNs Individually (per-label view):
#
# Enlarged Cardiomediastinum → 0: 3046  | 1: 446   | total: 3492
# Cardiomegaly              → 0: 3202  | 1: 400   | total: 3602
# Lung Opacity              → 0: 3167  | 1: 75    | total: 3242
# Lung Lesion               → 0: 3332  | 1: 123   | total: 3455
# Edema                     → 0: 3106  | 1: 70    | total: 3176
# Consolidation             → 0: 3047  | 1: 82    | total: 3129
# Pneumonia                 → 0: 3057  | 1: 120   | total: 3177
# Atelectasis               → 0: 3068  | 1: 576   | total: 3644
# Pneumothorax              → 0: 3295  | 1: 393   | total: 3688
# Pleural Effusion          → 0: 3038  | 1: 44    | total: 3082
# Pleural Other             → 0: 3310  | 1: 226   | total: 3536
# Fracture                  → 0: 3341  | 1: 55    | total: 3396
# Support Devices           → 0: 3067  | 1: 201   | total: 3268
