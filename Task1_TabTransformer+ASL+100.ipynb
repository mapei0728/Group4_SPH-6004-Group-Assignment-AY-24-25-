# %%
# Standard Libraries 
import os
import random
import pickle
from typing import Dict, List

# Third-Party Libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# PyTorch 
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# Evaluation (sklearn) 
from sklearn.metrics import (
    accuracy_score,
    average_precision_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score
)

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Define all pathologies list
pathologies = [
        "Enlarged Cardiomediastinum",
        "Cardiomegaly",
        "Lung Opacity",
        "Lung Lesion",
        "Edema",
        "Consolidation",
        "Pneumonia",
        "Atelectasis",
        "Pneumothorax",
        "Pleural Effusion",
        "Pleural Other",
        "Fracture",
        "Support Devices",
    ]

with open('X_train_100d_UMAP_AE.pkl', 'rb') as f:
    X_train = pickle.load(f)

with open('y_train.pkl', 'rb') as f:
    y_train = pickle.load(f)

with open('X_test_100d_UMAP_AE.pkl', 'rb') as f:
    X_test = pickle.load(f)

with open('y_test.pkl', 'rb') as f:
    y_test = pickle.load(f)

# If you actually intended X_valid, y_valid to be different sets:
with open('X_valid_100d_UMAP_AE.pkl', 'rb') as f:
    X_valid = pickle.load(f)

with open('y_valid.pkl', 'rb') as f:
    y_valid = pickle.load(f)

# %%
train_embeddings = X_train
train_labels = y_train
valid_embeddings = X_valid
valid_labels = y_valid
test_embeddings = X_test
test_labels = y_test

# %%
class SingleLabelDataset(Dataset):
    def __init__(self, embeddings, labels):
        self.embeddings = torch.tensor(embeddings, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.float32)

    def __len__(self):
        return len(self.embeddings)

    def __getitem__(self, idx):
        return {
            "embedding": self.embeddings[idx],
            "lab": self.labels[idx].unsqueeze(0)  #  shape: (1,)
        }

# %%
class TabTransformer(nn.Module):
    def __init__(self, input_dim=100, hidden_dim=128, output_dim=1, nhead=8, nlayers=4, dropout=0.1):
        super(TabTransformer, self).__init__()

        self.input_proj = nn.Linear(input_dim, hidden_dim)
        self.norm = nn.LayerNorm(hidden_dim)

        encoder_layer = self._build_encoder_layer(hidden_dim, nhead, dropout)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=nlayers)

        self.classifier = nn.Linear(hidden_dim, output_dim)

    def _build_encoder_layer(self, hidden_dim, nhead, dropout):
        return nn.TransformerEncoderLayer(
            d_model=hidden_dim,
            nhead=nhead,
            dim_feedforward=hidden_dim * 8,
            dropout=dropout,
            activation='gelu',
            batch_first=True
        )

    def forward(self, x):
        x = self.input_proj(x)
        x = self.norm(x)
        x = x.unsqueeze(1)
        x = self.encoder(x)
        x = x.squeeze(1)
        return self.classifier(x)

# %%
class MaskedAsymmetricLoss(nn.Module):
    def __init__(self, gamma_pos=0, gamma_neg=4):
        super().__init__()
        self.gamma_pos = gamma_pos
        self.gamma_neg = gamma_neg

    def forward(self, logits, labels, mask):
        probs = torch.sigmoid(logits)
        # Positive loss
        pos_loss = labels * torch.pow(1 - probs, self.gamma_pos) * torch.log(probs + 1e-8)
        # Negative loss
        neg_loss = (1 - labels) * torch.pow(probs, self.gamma_neg) * torch.log(1 - probs + 1e-8)
        # Combined loss
        loss = - (pos_loss + neg_loss)
        # Apply mask
        return (loss * mask).sum() / mask.sum()

# %%
def train_single_label_model(train_loader, val_loader, label_name, save_path):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model = TabTransformer().to(device)
    criterion = MaskedAsymmetricLoss(gamma_pos=0, gamma_neg=4)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

    for epoch in range(15):
        model.train()
        total_loss = 0

        for batch in train_loader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device)
            mask = torch.ones_like(y)

            logits = model(x)
            loss = criterion(logits, y, mask)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"[{label_name}] Epoch {epoch+1} - Training loss: {avg_loss:.4f}")

    torch.save(model.state_dict(), save_path)
    print(f"Model for {label_name} saved to {save_path}")

    return model

# %%
label_names =  [
    "Enlarged Cardiomediastinum", "Cardiomegaly", "Lung Opacity", "Lung Lesion",
    "Edema", "Consolidation", "Pneumonia", "Atelectasis",
    "Pneumothorax", "Pleural Effusion", "Pleural Other", "Fracture", "Support Devices"
]

def get_single_label_data(embeddings, labels, label_idx):
    mask = ~np.isnan(labels[:, label_idx])
    return embeddings[mask], labels[mask, label_idx]

for i, label_name in enumerate(label_names):
    print(f"\n Training model for: {label_name}")

    train_X, train_y = get_single_label_data(train_embeddings, train_labels, i)
    val_X, val_y = get_single_label_data(valid_embeddings, valid_labels, i)

    train_ds = SingleLabelDataset(train_X, train_y)
    val_ds = SingleLabelDataset(val_X, val_y)

    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=32, shuffle=False)

    model_path = f"transformer_label_{i}_{label_name}.pt"
    train_single_label_model(train_loader, val_loader, label_name, model_path)
# Out:
#  Training model for: Enlarged Cardiomediastinum
# [Enlarged Cardiomediastinum] Epoch 1 - Training loss: 0.1000
# [Enlarged Cardiomediastinum] Epoch 2 - Training loss: 0.0956
# [Enlarged Cardiomediastinum] Epoch 3 - Training loss: 0.0937
# [Enlarged Cardiomediastinum] Epoch 4 - Training loss: 0.0929
# [Enlarged Cardiomediastinum] Epoch 5 - Training loss: 0.0921
# [Enlarged Cardiomediastinum] Epoch 6 - Training loss: 0.0914
# [Enlarged Cardiomediastinum] Epoch 7 - Training loss: 0.0911
# [Enlarged Cardiomediastinum] Epoch 8 - Training loss: 0.0907
# [Enlarged Cardiomediastinum] Epoch 9 - Training loss: 0.0900
# [Enlarged Cardiomediastinum] Epoch 10 - Training loss: 0.0896
# [Enlarged Cardiomediastinum] Epoch 11 - Training loss: 0.0896
# [Enlarged Cardiomediastinum] Epoch 12 - Training loss: 0.0891
# [Enlarged Cardiomediastinum] Epoch 13 - Training loss: 0.0888
# [Enlarged Cardiomediastinum] Epoch 14 - Training loss: 0.0887
# [Enlarged Cardiomediastinum] Epoch 15 - Training loss: 0.0883
# Model for Enlarged Cardiomediastinum saved to transformer_label_0_Enlarged Cardiomediastinum.pt
#
#  Training model for: Cardiomegaly
# [Cardiomegaly] Epoch 1 - Training loss: 0.0939
# [Cardiomegaly] Epoch 2 - Training loss: 0.0882
# [Cardiomegaly] Epoch 3 - Training loss: 0.0868
# [Cardiomegaly] Epoch 4 - Training loss: 0.0855
# [Cardiomegaly] Epoch 5 - Training loss: 0.0850
# [Cardiomegaly] Epoch 6 - Training loss: 0.0844
# [Cardiomegaly] Epoch 7 - Training loss: 0.0838
# [Cardiomegaly] Epoch 8 - Training loss: 0.0836
# [Cardiomegaly] Epoch 9 - Training loss: 0.0831
# [Cardiomegaly] Epoch 10 - Training loss: 0.0827
# [Cardiomegaly] Epoch 11 - Training loss: 0.0828
# [Cardiomegaly] Epoch 12 - Training loss: 0.0827
# [Cardiomegaly] Epoch 13 - Training loss: 0.0822
# [Cardiomegaly] Epoch 14 - Training loss: 0.0821
# [Cardiomegaly] Epoch 15 - Training loss: 0.0819
# Model for Cardiomegaly saved to transformer_label_1_Cardiomegaly.pt
#
#  Training model for: Lung Opacity
# [Lung Opacity] Epoch 1 - Training loss: 0.0312
# [Lung Opacity] Epoch 2 - Training loss: 0.0282
# [Lung Opacity] Epoch 3 - Training loss: 0.0274
# [Lung Opacity] Epoch 4 - Training loss: 0.0268
# [Lung Opacity] Epoch 5 - Training loss: 0.0267
# [Lung Opacity] Epoch 6 - Training loss: 0.0264
# [Lung Opacity] Epoch 7 - Training loss: 0.0263
# [Lung Opacity] Epoch 8 - Training loss: 0.0262
# [Lung Opacity] Epoch 9 - Training loss: 0.0260
# [Lung Opacity] Epoch 10 - Training loss: 0.0259
# [Lung Opacity] Epoch 11 - Training loss: 0.0259
# [Lung Opacity] Epoch 12 - Training loss: 0.0257
# [Lung Opacity] Epoch 13 - Training loss: 0.0258
# [Lung Opacity] Epoch 14 - Training loss: 0.0254
# [Lung Opacity] Epoch 15 - Training loss: 0.0254
# Model for Lung Opacity saved to transformer_label_2_Lung Opacity.pt
#
#  Training model for: Lung Lesion
# [Lung Lesion] Epoch 1 - Training loss: 0.0368
# [Lung Lesion] Epoch 2 - Training loss: 0.0334
# [Lung Lesion] Epoch 3 - Training loss: 0.0325
# [Lung Lesion] Epoch 4 - Training loss: 0.0320
# [Lung Lesion] Epoch 5 - Training loss: 0.0317
# [Lung Lesion] Epoch 6 - Training loss: 0.0314
# [Lung Lesion] Epoch 7 - Training loss: 0.0310
# [Lung Lesion] Epoch 8 - Training loss: 0.0307
# [Lung Lesion] Epoch 9 - Training loss: 0.0304
# [Lung Lesion] Epoch 10 - Training loss: 0.0302
# [Lung Lesion] Epoch 11 - Training loss: 0.0300
# [Lung Lesion] Epoch 12 - Training loss: 0.0299
# [Lung Lesion] Epoch 13 - Training loss: 0.0297
# [Lung Lesion] Epoch 14 - Training loss: 0.0298
# [Lung Lesion] Epoch 15 - Training loss: 0.0297
# Model for Lung Lesion saved to transformer_label_3_Lung Lesion.pt
#
#  Training model for: Edema
# [Edema] Epoch 1 - Training loss: 0.0310
# [Edema] Epoch 2 - Training loss: 0.0262
# [Edema] Epoch 3 - Training loss: 0.0259
# [Edema] Epoch 4 - Training loss: 0.0255
# [Edema] Epoch 5 - Training loss: 0.0256
# [Edema] Epoch 6 - Training loss: 0.0255
# [Edema] Epoch 7 - Training loss: 0.0253
# [Edema] Epoch 8 - Training loss: 0.0254
# [Edema] Epoch 9 - Training loss: 0.0253
# [Edema] Epoch 10 - Training loss: 0.0252
# [Edema] Epoch 11 - Training loss: 0.0250
# [Edema] Epoch 12 - Training loss: 0.0252
# [Edema] Epoch 13 - Training loss: 0.0250
# [Edema] Epoch 14 - Training loss: 0.0249
# [Edema] Epoch 15 - Training loss: 0.0250
# Model for Edema saved to transformer_label_4_Edema.pt
#
#  Training model for: Consolidation
# [Consolidation] Epoch 1 - Training loss: 0.0401
# [Consolidation] Epoch 2 - Training loss: 0.0381
# [Consolidation] Epoch 3 - Training loss: 0.0376
# [Consolidation] Epoch 4 - Training loss: 0.0375
# [Consolidation] Epoch 5 - Training loss: 0.0376
# [Consolidation] Epoch 6 - Training loss: 0.0372
# [Consolidation] Epoch 7 - Training loss: 0.0372
# [Consolidation] Epoch 8 - Training loss: 0.0369
# [Consolidation] Epoch 9 - Training loss: 0.0368
# [Consolidation] Epoch 10 - Training loss: 0.0367
# [Consolidation] Epoch 11 - Training loss: 0.0368
# [Consolidation] Epoch 12 - Training loss: 0.0366
# [Consolidation] Epoch 13 - Training loss: 0.0366
# [Consolidation] Epoch 14 - Training loss: 0.0365
# [Consolidation] Epoch 15 - Training loss: 0.0364
# Model for Consolidation saved to transformer_label_5_Consolidation.pt
#
#  Training model for: Pneumonia
# [Pneumonia] Epoch 1 - Training loss: 0.0461
# [Pneumonia] Epoch 2 - Training loss: 0.0436
# [Pneumonia] Epoch 3 - Training loss: 0.0431
# [Pneumonia] Epoch 4 - Training loss: 0.0429
# [Pneumonia] Epoch 5 - Training loss: 0.0425
# [Pneumonia] Epoch 6 - Training loss: 0.0421
# [Pneumonia] Epoch 7 - Training loss: 0.0419
# [Pneumonia] Epoch 8 - Training loss: 0.0417
# [Pneumonia] Epoch 9 - Training loss: 0.0418
# [Pneumonia] Epoch 10 - Training loss: 0.0416
# [Pneumonia] Epoch 11 - Training loss: 0.0415
# [Pneumonia] Epoch 12 - Training loss: 0.0416
# [Pneumonia] Epoch 13 - Training loss: 0.0411
# [Pneumonia] Epoch 14 - Training loss: 0.0411
# [Pneumonia] Epoch 15 - Training loss: 0.0410
# Model for Pneumonia saved to transformer_label_6_Pneumonia.pt
#
#  Training model for: Atelectasis
# [Atelectasis] Epoch 1 - Training loss: 0.1236
# [Atelectasis] Epoch 2 - Training loss: 0.1191
# [Atelectasis] Epoch 3 - Training loss: 0.1173
# [Atelectasis] Epoch 4 - Training loss: 0.1164
# [Atelectasis] Epoch 5 - Training loss: 0.1158
# [Atelectasis] Epoch 6 - Training loss: 0.1152
# [Atelectasis] Epoch 7 - Training loss: 0.1148
# [Atelectasis] Epoch 8 - Training loss: 0.1140
# [Atelectasis] Epoch 9 - Training loss: 0.1139
# [Atelectasis] Epoch 10 - Training loss: 0.1136
# [Atelectasis] Epoch 11 - Training loss: 0.1129
# [Atelectasis] Epoch 12 - Training loss: 0.1127
# [Atelectasis] Epoch 13 - Training loss: 0.1127
# [Atelectasis] Epoch 14 - Training loss: 0.1123
# [Atelectasis] Epoch 15 - Training loss: 0.1119
# Model for Atelectasis saved to transformer_label_7_Atelectasis.pt
#
#  Training model for: Pneumothorax
# [Pneumothorax] Epoch 1 - Training loss: 0.0855
# [Pneumothorax] Epoch 2 - Training loss: 0.0768
# [Pneumothorax] Epoch 3 - Training loss: 0.0749
# [Pneumothorax] Epoch 4 - Training loss: 0.0733
# [Pneumothorax] Epoch 5 - Training loss: 0.0726
# [Pneumothorax] Epoch 6 - Training loss: 0.0717
# [Pneumothorax] Epoch 7 - Training loss: 0.0707
# [Pneumothorax] Epoch 8 - Training loss: 0.0701
# [Pneumothorax] Epoch 9 - Training loss: 0.0692
# [Pneumothorax] Epoch 10 - Training loss: 0.0694
# [Pneumothorax] Epoch 11 - Training loss: 0.0689
# [Pneumothorax] Epoch 12 - Training loss: 0.0686
# [Pneumothorax] Epoch 13 - Training loss: 0.0680
# [Pneumothorax] Epoch 14 - Training loss: 0.0679
# [Pneumothorax] Epoch 15 - Training loss: 0.0676
# Model for Pneumothorax saved to transformer_label_8_Pneumothorax.pt
#
#  Training model for: Pleural Effusion
# [Pleural Effusion] Epoch 1 - Training loss: 0.0213
# [Pleural Effusion] Epoch 2 - Training loss: 0.0188
# [Pleural Effusion] Epoch 3 - Training loss: 0.0185
# [Pleural Effusion] Epoch 4 - Training loss: 0.0182
# [Pleural Effusion] Epoch 5 - Training loss: 0.0180
# [Pleural Effusion] Epoch 6 - Training loss: 0.0178
# [Pleural Effusion] Epoch 7 - Training loss: 0.0179
# [Pleural Effusion] Epoch 8 - Training loss: 0.0178
# [Pleural Effusion] Epoch 9 - Training loss: 0.0177
# [Pleural Effusion] Epoch 10 - Training loss: 0.0176
# [Pleural Effusion] Epoch 11 - Training loss: 0.0176
# [Pleural Effusion] Epoch 12 - Training loss: 0.0173
# [Pleural Effusion] Epoch 13 - Training loss: 0.0175
# [Pleural Effusion] Epoch 14 - Training loss: 0.0172
# [Pleural Effusion] Epoch 15 - Training loss: 0.0174
# Model for Pleural Effusion saved to transformer_label_9_Pleural Effusion.pt
#
#  Training model for: Pleural Other
# [Pleural Other] Epoch 1 - Training loss: 0.0676
# [Pleural Other] Epoch 2 - Training loss: 0.0633
# [Pleural Other] Epoch 3 - Training loss: 0.0621
# [Pleural Other] Epoch 4 - Training loss: 0.0618
# [Pleural Other] Epoch 5 - Training loss: 0.0613
# [Pleural Other] Epoch 6 - Training loss: 0.0605
# [Pleural Other] Epoch 7 - Training loss: 0.0604
# [Pleural Other] Epoch 8 - Training loss: 0.0602
# [Pleural Other] Epoch 9 - Training loss: 0.0600
# [Pleural Other] Epoch 10 - Training loss: 0.0600
# [Pleural Other] Epoch 11 - Training loss: 0.0597
# [Pleural Other] Epoch 12 - Training loss: 0.0597
# [Pleural Other] Epoch 13 - Training loss: 0.0598
# [Pleural Other] Epoch 14 - Training loss: 0.0599
# [Pleural Other] Epoch 15 - Training loss: 0.0595
# Model for Pleural Other saved to transformer_label_10_Pleural Other.pt
#
#  Training model for: Fracture
# [Fracture] Epoch 1 - Training loss: 0.0236
# [Fracture] Epoch 2 - Training loss: 0.0208
# [Fracture] Epoch 3 - Training loss: 0.0205
# [Fracture] Epoch 4 - Training loss: 0.0200
# [Fracture] Epoch 5 - Training loss: 0.0198
# [Fracture] Epoch 6 - Training loss: 0.0196
# [Fracture] Epoch 7 - Training loss: 0.0195
# [Fracture] Epoch 8 - Training loss: 0.0193
# [Fracture] Epoch 9 - Training loss: 0.0193
# [Fracture] Epoch 10 - Training loss: 0.0192
# [Fracture] Epoch 11 - Training loss: 0.0191
# [Fracture] Epoch 12 - Training loss: 0.0189
# [Fracture] Epoch 13 - Training loss: 0.0190
# [Fracture] Epoch 14 - Training loss: 0.0189
# [Fracture] Epoch 15 - Training loss: 0.0189
# Model for Fracture saved to transformer_label_11_Fracture.pt
#
#  Training model for: Support Devices
# [Support Devices] Epoch 1 - Training loss: 0.0555
# [Support Devices] Epoch 2 - Training loss: 0.0534
# [Support Devices] Epoch 3 - Training loss: 0.0527
# [Support Devices] Epoch 4 - Training loss: 0.0525
# [Support Devices] Epoch 5 - Training loss: 0.0521
# [Support Devices] Epoch 6 - Training loss: 0.0520
# [Support Devices] Epoch 7 - Training loss: 0.0518
# [Support Devices] Epoch 8 - Training loss: 0.0517
# [Support Devices] Epoch 9 - Training loss: 0.0517
# [Support Devices] Epoch 10 - Training loss: 0.0514
# [Support Devices] Epoch 11 - Training loss: 0.0512
# [Support Devices] Epoch 12 - Training loss: 0.0512
# [Support Devices] Epoch 13 - Training loss: 0.0510
# [Support Devices] Epoch 14 - Training loss: 0.0510
# [Support Devices] Epoch 15 - Training loss: 0.0509
# Model for Support Devices saved to transformer_label_12_Support Devices.pt

# %%
def evaluate_model(model, dataloader, device):
    model.eval()
    all_probs = []
    all_targets = []

    with torch.no_grad():
        for batch in dataloader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device).squeeze()  # shape: (batch_size,)

            logits = model(x).squeeze()  # shape: (batch_size,)
            probs = torch.sigmoid(logits)

            all_probs.extend(probs.cpu().numpy())
            all_targets.extend(y.cpu().numpy())

    try:
        auc = roc_auc_score(all_targets, all_probs)
    except ValueError:
        auc = float('nan')

    return auc

# %%
for i, label_name in enumerate(label_names):
    print(f"\n Testing model for: {label_name}")

    # 1. Prepare test data for the current label
    test_X, test_y = get_single_label_data(test_embeddings, test_labels, i)
    test_ds = SingleLabelDataset(test_X, test_y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # 2. Rebuild the model architecture and load saved weights
    model = TabTransformer(input_dim=100, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)

    # 3. Evaluate on the test set
    test_auc = evaluate_model(model, test_loader, device)
    print(f"[{label_name}] Test AUC: {test_auc:.4f}")
# Out:
#  Testing model for: Enlarged Cardiomediastinum
# [Enlarged Cardiomediastinum] Test AUC: 0.8893
#
#  Testing model for: Cardiomegaly
# [Cardiomegaly] Test AUC: 0.8967
#
#  Testing model for: Lung Opacity
# [Lung Opacity] Test AUC: 0.8958
#
#  Testing model for: Lung Lesion
# [Lung Lesion] Test AUC: 0.9507
#
#  Testing model for: Edema
# [Edema] Test AUC: 0.7861
#
#  Testing model for: Consolidation
# [Consolidation] Test AUC: 0.7126
#
#  Testing model for: Pneumonia
# [Pneumonia] Test AUC: 0.8731
#
#  Testing model for: Atelectasis
# [Atelectasis] Test AUC: 0.8477
#
#  Testing model for: Pneumothorax
# [Pneumothorax] Test AUC: 0.9350
#
#  Testing model for: Pleural Effusion
# [Pleural Effusion] Test AUC: 0.9071
#
#  Testing model for: Pleural Other
# [Pleural Other] Test AUC: 0.8227
#
#  Testing model for: Fracture
# [Fracture] Test AUC: 0.9026
#
#  Testing model for: Support Devices
# [Support Devices] Test AUC: 0.9097

# %%
def safe_get(report, class_label, metric):
    """
    Safely extract a specific class or average metric.
    - For class_label as 0 or 1, try multiple key formats;
    - For average entries like 'macro avg', lookup directly.
    """
    if isinstance(class_label, (int, float)):
        keys_to_try = [class_label, str(class_label), f"{float(class_label):.1f}"]
    else:
        keys_to_try = [class_label]

    for key in keys_to_try:
        if key in report and metric in report[key]:
            return report[key][metric]
    return np.nan

def evaluate_full_report(model, dataloader, device):
    model.eval()
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for batch in dataloader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device)

            logits = model(x)
            probs = torch.sigmoid(logits)
            preds = (probs > 0.5).float()

            all_labels.extend(y.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    # accuracy: how many predictions match ground truth
    accuracy = (np.array(all_labels) == np.array(all_preds)).mean()

    return classification_report(all_labels, all_preds, digits=4, output_dict=True), accuracy

# Collect reports for all labels
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
report_dict = {}

for i, label_name in enumerate(label_names):
    print("=" * 30)
    print(f" Test Evaluation Report for: {label_name}")
    print("=" * 30)

    # 1. Load test data for current label
    test_X, test_y = get_single_label_data(test_embeddings, test_labels, i)
    test_ds = SingleLabelDataset(test_X, test_y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # 2. Load corresponding model
    model = TabTransformer(input_dim=100, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)

    # 3. Get classification report + accuracy
    report, acc = evaluate_full_report(model, test_loader, device)

    report_dict[label_name] = {
        # Class 0
        'precision_0': safe_get(report, 0, 'precision'),
        'recall_0': safe_get(report, 0, 'recall'),
        'f1-score_0': safe_get(report, 0, 'f1-score'),

        # Class 1
        'precision_1': safe_get(report, 1, 'precision'),
        'recall_1': safe_get(report, 1, 'recall'),
        'f1-score_1': safe_get(report, 1, 'f1-score'),

        # Macro avg
        'precision': safe_get(report, 'macro avg', 'precision'),
        'recall': safe_get(report, 'macro avg', 'recall'),
        'f1-score': safe_get(report, 'macro avg', 'f1-score'),
        'support': safe_get(report, 'macro avg', 'support'),

        # Accuracy
        'accuracy': acc
    }

# Save as DataFrame
df = pd.DataFrame(report_dict)
df.index.name = "Metric"
df = df.round(4)
df.to_csv("test_metrics_per_label.csv")
print("\n Saved report with accuracy to: test_metrics_per_label.csv")
# Out:
# ==============================
#  Test Evaluation Report for: Enlarged Cardiomediastinum
# ==============================
# ==============================
#  Test Evaluation Report for: Cardiomegaly
# ==============================
# ==============================
#  Test Evaluation Report for: Lung Opacity
# ==============================
# ==============================
#  Test Evaluation Report for: Lung Lesion
# ==============================
# ==============================
#  Test Evaluation Report for: Edema
# ==============================
# ==============================
#  Test Evaluation Report for: Consolidation
# ==============================
# ==============================
#  Test Evaluation Report for: Pneumonia
# ==============================
# ==============================
#  Test Evaluation Report for: Atelectasis
# ==============================
# ==============================
#  Test Evaluation Report for: Pneumothorax
# ==============================
# ==============================
#  Test Evaluation Report for: Pleural Effusion
# ==============================
# ==============================
#  Test Evaluation Report for: Pleural Other
# ==============================
# ==============================
#  Test Evaluation Report for: Fracture
# ==============================
# ==============================
#  Test Evaluation Report for: Support Devices
# ==============================
#
#  Saved report with accuracy to: test_metrics_per_label.csv

# %%
def evaluate_auc_ap(model, dataloader, device):
    model.eval()
    all_probs = []
    all_targets = []

    with torch.no_grad():
        for batch in dataloader:
            x = batch["embedding"].to(device)
            y = batch["lab"].to(device).squeeze()

            logits = model(x).squeeze()
            probs = torch.sigmoid(logits)

            all_probs.extend(probs.cpu().numpy())
            all_targets.extend(y.cpu().numpy())

    try:
        auc = roc_auc_score(all_targets, all_probs)
    except ValueError:
        auc = float('nan')

    try:
        ap = average_precision_score(all_targets, all_probs)
    except ValueError:
        ap = float('nan')

    return auc, ap

#  Evaluate on Test Set
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for i, label_name in enumerate(label_names):
    print("=" * 40)
    print(f" Test Metrics for: {label_name}")
    print("=" * 40)

    # 1. Load test data
    test_X, test_y = get_single_label_data(test_embeddings, test_labels, i)
    test_ds = SingleLabelDataset(test_X, test_y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # 2. Load model
    model = TabTransformer(input_dim=100, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)

    # 3. Evaluate
    auc, ap = evaluate_auc_ap(model, test_loader, device)
    print(f"AUC Score:              {auc:.4f}")
    print(f"Average Precision (AP): {ap:.4f}\n")
# Out:
# ========================================
#  Test Metrics for: Enlarged Cardiomediastinum
# ========================================
# AUC Score:              0.8893
# Average Precision (AP): 0.5393
#
# ========================================
#  Test Metrics for: Cardiomegaly
# ========================================
# AUC Score:              0.8967
# Average Precision (AP): 0.5426
#
# ========================================
#  Test Metrics for: Lung Opacity
# ========================================
# AUC Score:              0.8958
# Average Precision (AP): 0.2604
#
# ========================================
#  Test Metrics for: Lung Lesion
# ========================================
# AUC Score:              0.9507
# Average Precision (AP): 0.5041
#
# ========================================
#  Test Metrics for: Edema
# ========================================
# AUC Score:              0.7861
# Average Precision (AP): 0.1092
#
# ========================================
#  Test Metrics for: Consolidation
# ========================================
# AUC Score:              0.7126
# Average Precision (AP): 0.1042
#
# ========================================
#  Test Metrics for: Pneumonia
# ========================================
# AUC Score:              0.8731
# Average Precision (AP): 0.2829
#
# ========================================
#  Test Metrics for: Atelectasis
# ========================================
# AUC Score:              0.8477
# Average Precision (AP): 0.5289
#
# ========================================
#  Test Metrics for: Pneumothorax
# ========================================
# AUC Score:              0.9350
# Average Precision (AP): 0.6583
#
# ========================================
#  Test Metrics for: Pleural Effusion
# ========================================
# AUC Score:              0.9071
# Average Precision (AP): 0.1574
#
# ========================================
#  Test Metrics for: Pleural Other
# ========================================
# AUC Score:              0.8227
# Average Precision (AP): 0.3547
#
# ========================================
#  Test Metrics for: Fracture
# ========================================
# AUC Score:              0.9026
# Average Precision (AP): 0.1647
#
# ========================================
#  Test Metrics for: Support Devices
# ========================================
# AUC Score:              0.9097
# Average Precision (AP): 0.3757

# %%
#  Evaluate multi-label classification models on the test set
#  Strategy: Per-label evaluation by skipping NaNs individually
#  Step 1: Predict each label individually, skipping NaNs

all_true = []
all_pred = []

for i, label_name in enumerate(label_names):
    print(f"Evaluating label: {label_name}")

    # Select non-NaN samples for this label
    mask = ~np.isnan(test_labels[:, i])
    X = test_embeddings[mask]
    y = test_labels[mask, i]

    test_ds = SingleLabelDataset(X, y)
    test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)

    # Load model
    model = TabTransformer(input_dim=100, hidden_dim=128, output_dim=1)
    model.load_state_dict(torch.load(f"transformer_label_{i}_{label_name}.pt"))
    model = model.to(device)
    model.eval()

    preds = []
    true_vals = []

    with torch.no_grad():
        for batch in test_loader:
            x = batch["embedding"].to(device)
            y_batch = batch["lab"].to(device)

            logits = model(x)
            probs = torch.sigmoid(logits)
            preds.extend(probs.cpu().numpy())  # Use raw probabilities for PR-AUC
            true_vals.extend(y_batch.cpu().numpy())

    all_pred.append(np.array(preds).flatten())
    all_true.append(np.array(true_vals).flatten())

# Step 2: Compute metrics 
micro_acc = accuracy_score(
    np.concatenate([t.round() for t in all_true]),
    np.concatenate([p > 0.5 for p in all_pred])
)
macro_acc = np.mean([
    accuracy_score(all_true[i].round(), (all_pred[i] > 0.5).astype(int)) for i in range(len(label_names))
])

# Step 3: Compute PR-AUC per label
pr_auc_per_label = []
for i in range(len(label_names)):
    if len(np.unique(all_true[i])) > 1:
        auc = average_precision_score(all_true[i], all_pred[i])
        pr_auc_per_label.append(auc)
    else:
        pr_auc_per_label.append(np.nan)  # Cannot compute AUC with one class only

# Step 4: Print results
print("\n Evaluation on Test Set using per-label skipping of NaNs:")
print(f"Micro Accuracy (label-wise overall):     {micro_acc:.4f}")
print(f"Macro Accuracy (avg per label):          {macro_acc:.4f}")

print("\n Per-Label PR-AUC (Precision-Recall AUC):")
for i, label_name in enumerate(label_names):
    auc = pr_auc_per_label[i]
    print(f"{label_name:<25} → PR-AUC: {auc:.4f}" if not np.isnan(auc) else f"{label_name:<25} → PR-AUC: N/A")

macro_pr_auc = np.nanmean(pr_auc_per_label)
print(f"\nMacro PR-AUC (avg across labels): {macro_pr_auc:.4f}")

print("\n Label-wise Distribution After Skipping NaNs Individually (per-label view):\n")

for i, label_name in enumerate(label_names):
    label_vals = test_labels[:, i]
    valid_mask = ~np.isnan(label_vals)
    label_clean = label_vals[valid_mask]

    count_0 = np.sum(label_clean == 0)
    count_1 = np.sum(label_clean == 1)
    print(f"{label_name:<25} → 0: {count_0:<5} | 1: {count_1:<5} | total: {len(label_clean):<5}")
# Out:
# Evaluating label: Enlarged Cardiomediastinum
# Evaluating label: Cardiomegaly
# Evaluating label: Lung Opacity
# Evaluating label: Lung Lesion
# Evaluating label: Edema
# Evaluating label: Consolidation
# Evaluating label: Pneumonia
# Evaluating label: Atelectasis
# Evaluating label: Pneumothorax
# Evaluating label: Pleural Effusion
# Evaluating label: Pleural Other
# Evaluating label: Fracture
# Evaluating label: Support Devices
#
#  Evaluation on Test Set using per-label skipping of NaNs:
# Micro Accuracy (label-wise overall):     0.9157
# Macro Accuracy (avg per label):          0.9182
#
#  Per-Label PR-AUC (Precision-Recall AUC):
# Enlarged Cardiomediastinum → PR-AUC: 0.5393
# Cardiomegaly              → PR-AUC: 0.5426
# Lung Opacity              → PR-AUC: 0.2604
# Lung Lesion               → PR-AUC: 0.5041
# Edema                     → PR-AUC: 0.1092
# Consolidation             → PR-AUC: 0.1042
# Pneumonia                 → PR-AUC: 0.2829
# Atelectasis               → PR-AUC: 0.5289
# Pneumothorax              → PR-AUC: 0.6583
# Pleural Effusion          → PR-AUC: 0.1574
# Pleural Other             → PR-AUC: 0.3547
# Fracture                  → PR-AUC: 0.1647
# Support Devices           → PR-AUC: 0.3757
#
# Macro PR-AUC (avg across labels): 0.3525
#
#  Label-wise Distribution After Skipping NaNs Individually (per-label view):
#
# Enlarged Cardiomediastinum → 0: 3046  | 1: 446   | total: 3492
# Cardiomegaly              → 0: 3202  | 1: 400   | total: 3602
# Lung Opacity              → 0: 3167  | 1: 75    | total: 3242
# Lung Lesion               → 0: 3332  | 1: 123   | total: 3455
# Edema                     → 0: 3106  | 1: 70    | total: 3176
# Consolidation             → 0: 3047  | 1: 82    | total: 3129
# Pneumonia                 → 0: 3057  | 1: 120   | total: 3177
# Atelectasis               → 0: 3068  | 1: 576   | total: 3644
# Pneumothorax              → 0: 3295  | 1: 393   | total: 3688
# Pleural Effusion          → 0: 3038  | 1: 44    | total: 3082
# Pleural Other             → 0: 3310  | 1: 226   | total: 3536
# Fracture                  → 0: 3341  | 1: 55    | total: 3396
# Support Devices           → 0: 3067  | 1: 201   | total: 3268
