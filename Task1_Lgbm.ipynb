# %% [markdown]
# ### Mounting data to the working directory
# Upload your data folder into google drive. Once done run the cell below. Now if you open the `files` tab on the left, you will see that a new folder `drive` is mounted. You will be able find your data in the folder.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Task: 13 labels for each sample that we need to predict from the embedding

# %% [markdown]
# - multi-label classification (NOT multi-class) --> things can have 2 labels
# - Can train one model per label (binary)

# %%
import pickle
from imblearn.over_sampling import SMOTE
import numpy as np
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, roc_auc_score, average_precision_score
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
with open('/content/drive/MyDrive/SPH6004_project/data/X_train.pkl', 'rb') as f:
    train_embeddings = pickle.load(f)

with open('/content/drive/MyDrive/SPH6004_project/data/y_train.pkl', 'rb') as f:
    train_labels = pickle.load(f)

with open('/content/drive/MyDrive/SPH6004_project/data/X_valid.pkl', 'rb') as f:
    valid_embeddings = pickle.load(f)

with open('/content/drive/MyDrive/SPH6004_project/data/y_valid.pkl', 'rb') as f:
    valid_labels = pickle.load(f)

with open('/content/drive/MyDrive/SPH6004_project/data/X_test.pkl', 'rb') as f:
    test_embeddings = pickle.load(f)

with open('/content/drive/MyDrive/SPH6004_project/data/y_test.pkl', 'rb') as f:
    test_labels = pickle.load(f)

# %%
train_embeddings = np.array(train_embeddings)
train_labels = np.array(train_labels)
valid_embeddings = np.array(valid_embeddings)
valid_labels = np.array(valid_labels)

train_embeddings.shape
# Out:
# (36502, 1376)

# %%
train_labels.shape
# Out:
# (36502, 13)

# %%
valid_embeddings.shape
# Out:
# (4563, 1376)

# %%
valid_labels.shape
# Out:
# (4563, 13)

# %%
test_embeddings.shape
# Out:
# (4562, 1376)

# %%
test_labels.shape
# Out:
# (4562, 13)

# %%
#check class balance in the training data
for label_idx in range(train_labels.shape[1]):
    total_samples = train_labels.shape[0]

    # Identify NaN values
    nan_mask = np.isnan(train_labels[:, label_idx])
    nan_count = np.sum(nan_mask)

    # Filter valid (non-NaN) labels
    valid_idx = ~nan_mask
    y_train = train_labels[valid_idx, label_idx].astype(int)

    # Count occurrences of each class (0 and 1)
    class_counts = np.bincount(y_train, minlength=2)  # Ensure [0, 1] bins exist

    print(f"Label {label_idx}:")
    print(f"  Class 0: {class_counts[0]} samples ({class_counts[0] / total_samples:.2%})")
    print(f"  Class 1: {class_counts[1]} samples ({class_counts[1] / total_samples:.2%})")
    print(f"  NaN: {nan_count} samples ({nan_count / total_samples:.2%})\n")
# Out:
# Label 0:
#   Class 0: 24778 samples (67.88%)
#   Class 1: 3222 samples (8.83%)
#   NaN: 8502 samples (23.29%)
#
# Label 1:
#   Class 0: 25852 samples (70.82%)
#   Class 1: 2982 samples (8.17%)
#   NaN: 7668 samples (21.01%)
#
# Label 2:
#   Class 0: 25851 samples (70.82%)
#   Class 1: 650 samples (1.78%)
#   NaN: 10001 samples (27.40%)
#
# Label 3:
#   Class 0: 26884 samples (73.65%)
#   Class 1: 928 samples (2.54%)
#   NaN: 8690 samples (23.81%)
#
# Label 4:
#   Class 0: 25213 samples (69.07%)
#   Class 1: 553 samples (1.51%)
#   NaN: 10736 samples (29.41%)
#
# Label 5:
#   Class 0: 24784 samples (67.90%)
#   Class 1: 788 samples (2.16%)
#   NaN: 10930 samples (29.94%)
#
# Label 6:
#   Class 0: 24834 samples (68.03%)
#   Class 1: 1050 samples (2.88%)
#   NaN: 10618 samples (29.09%)
#
# Label 7:
#   Class 0: 24953 samples (68.36%)
#   Class 1: 4306 samples (11.80%)
#   NaN: 7243 samples (19.84%)
#
# Label 8:
#   Class 0: 26732 samples (73.23%)
#   Class 1: 2971 samples (8.14%)
#   NaN: 6799 samples (18.63%)
#
# Label 9:
#   Class 0: 24709 samples (67.69%)
#   Class 1: 384 samples (1.05%)
#   NaN: 11409 samples (31.26%)
#
# Label 10:
#   Class 0: 26674 samples (73.08%)
#   Class 1: 1745 samples (4.78%)
#   NaN: 8083 samples (22.14%)
#
# Label 11:
#   Class 0: 26898 samples (73.69%)
#   Class 1: 455 samples (1.25%)
#   NaN: 9149 samples (25.06%)
#
# Label 12:
#   Class 0: 24940 samples (68.33%)
#   Class 1: 1572 samples (4.31%)
#   NaN: 9990 samples (27.37%)

# %%
#ignore the NA values and output class balance
for label_idx in range(train_labels.shape[1]):
    valid_idx = ~np.isnan(train_labels[:, label_idx])
    y_train = train_labels[valid_idx, label_idx].astype(int)

    class_counts = np.bincount(y_train)
    total_samples = len(y_train)

    print(f"Label {label_idx}:")
    for cls, count in enumerate(class_counts):
        print(f"  Class {cls}: {count} samples ({count/total_samples:.2%})")
    print()
# Out:
# Label 0:
#   Class 0: 24778 samples (88.49%)
#   Class 1: 3222 samples (11.51%)
#
# Label 1:
#   Class 0: 25852 samples (89.66%)
#   Class 1: 2982 samples (10.34%)
#
# Label 2:
#   Class 0: 25851 samples (97.55%)
#   Class 1: 650 samples (2.45%)
#
# Label 3:
#   Class 0: 26884 samples (96.66%)
#   Class 1: 928 samples (3.34%)
#
# Label 4:
#   Class 0: 25213 samples (97.85%)
#   Class 1: 553 samples (2.15%)
#
# Label 5:
#   Class 0: 24784 samples (96.92%)
#   Class 1: 788 samples (3.08%)
#
# Label 6:
#   Class 0: 24834 samples (95.94%)
#   Class 1: 1050 samples (4.06%)
#
# Label 7:
#   Class 0: 24953 samples (85.28%)
#   Class 1: 4306 samples (14.72%)
#
# Label 8:
#   Class 0: 26732 samples (90.00%)
#   Class 1: 2971 samples (10.00%)
#
# Label 9:
#   Class 0: 24709 samples (98.47%)
#   Class 1: 384 samples (1.53%)
#
# Label 10:
#   Class 0: 26674 samples (93.86%)
#   Class 1: 1745 samples (6.14%)
#
# Label 11:
#   Class 0: 26898 samples (98.34%)
#   Class 1: 455 samples (1.66%)
#
# Label 12:
#   Class 0: 24940 samples (94.07%)
#   Class 1: 1572 samples (5.93%)

# %% [markdown]
# class imbalance, better to use average precision for training?, and smote can help too probably

# %%
#get number of labels
num_labels = train_labels.shape[1]

# %%
# Train one model per label, each model for each label is a binary task
models = {}
best_params_per_label = {}

# Define param grid
param_list = [
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": 5, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": 5, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": 5, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": 7, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": 7, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": 7, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": -1, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": -1, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": -1, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": 3, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": 3, "n_estimators": 100},
    {"learning_rate": 0.1, "max_depth": 5, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": 5, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": 5, "n_estimators": 100},
    {"learning_rate": 0.1, "max_depth": 7, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": 7, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": 7, "n_estimators": 100},
    {"learning_rate": 0.1, "max_depth": -1, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": -1, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": -1, "n_estimators": 100},

]

for label_idx in range(num_labels):
    print(f"\nTraining model for label {label_idx + 1}/{num_labels}")

    # Filter for non-NA samples for this label in train and validation sets
    train_idx = ~np.isnan(train_labels[:, label_idx])
    val_idx = ~np.isnan(valid_labels[:, label_idx])

    x_train = train_embeddings[train_idx]
    y_train = train_labels[train_idx, label_idx].astype(int)

    x_val = valid_embeddings[val_idx]
    y_val = valid_labels[val_idx, label_idx].astype(int)

    # Check class distribution before SMOTE
    class_0, class_1 = np.bincount(y_train)
    print(f"  Before SMOTE - Class 0: {class_0}, Class 1: {class_1}")

    smote = SMOTE(sampling_strategy='auto', random_state=42)
    x_train, y_train = smote.fit_resample(x_train, y_train)

    # Check class distribution after SMOTE
    class_0_res, class_1_res = np.bincount(y_train)
    print(f"  After SMOTE  - Class 0: {class_0_res}, Class 1: {class_1_res}")

    best_pr_auc = 0
    best_model = None
    best_params = None

    for params in param_list:
        model = LGBMClassifier(objective="binary", boosting_type="gbdt", verbose=-1, **params)
        model.fit(x_train, y_train)

        val_probs = model.predict_proba(x_val)[:, 1]
        pr_auc = average_precision_score(y_val, val_probs)
        #auc = roc_auc_score(y_val, val_probs)

        print(f"  Params: {params}, Validation PR-AUC: {pr_auc:.4f}")

        if pr_auc > best_pr_auc:
            best_pr_auc = pr_auc
            best_model = model
            best_params = params

    print(f"Best Params for label {label_idx}: {best_params}, PR-AUC: {best_pr_auc:.4f}")
    models[label_idx] = best_model
    best_params_per_label[label_idx] = best_params
# Out:
# Training model for label 1/13
#   Before SMOTE - Class 0: 24778, Class 1: 3222
#   After SMOTE  - Class 0: 24778, Class 1: 24778
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.5145
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5165
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5260
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5114
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5261
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5319
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5171
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5288
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5327
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5163
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5262
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5256
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.5145
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5336
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5380
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5274
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5342
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5202
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5337
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5289
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5235
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5202
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.4993
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.4944
# Best Params for label 0: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, PR-AUC: 0.5380
#
# Training model for label 2/13
#   Before SMOTE - Class 0: 25852, Class 1: 2982
#   After SMOTE  - Class 0: 25852, Class 1: 25852
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4914
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5025
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5073
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5043
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5283
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5292
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5124
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5227
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5308
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5108
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5223
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5243
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4914
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5284
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5279
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5255
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5273
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5181
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5398
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5236
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5218
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5498
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5311
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5247
# Best Params for label 1: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, PR-AUC: 0.5498
#
# Training model for label 3/13
#   Before SMOTE - Class 0: 25851, Class 1: 650
#   After SMOTE  - Class 0: 25851, Class 1: 25851
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2983
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.2967
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2913
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3194
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3353
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3272
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3133
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3358
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3432
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3145
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3424
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3369
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2983
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3252
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3192
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3202
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3123
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.2907
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3242
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.2892
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.2872
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3259
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3198
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.2971
# Best Params for label 2: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, PR-AUC: 0.3432
#
# Training model for label 4/13
#   Before SMOTE - Class 0: 26884, Class 1: 928
#   After SMOTE  - Class 0: 26884, Class 1: 26884
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2620
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.2852
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3147
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.2974
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3035
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3067
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.2969
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3201
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3254
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2983
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3142
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3291
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2620
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3680
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3537
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3614
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3522
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3494
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3767
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3437
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3513
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3567
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3393
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3462
# Best Params for label 3: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, PR-AUC: 0.3767
#
# Training model for label 5/13
#   Before SMOTE - Class 0: 25213, Class 1: 553
#   After SMOTE  - Class 0: 25213, Class 1: 25213
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1412
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1454
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1443
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1487
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1690
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1759
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1577
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1624
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1686
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1531
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1647
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1589
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1412
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1910
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1743
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1574
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1561
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1446
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1858
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1705
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1674
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1439
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1460
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1416
# Best Params for label 4: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, PR-AUC: 0.1910
#
# Training model for label 6/13
#   Before SMOTE - Class 0: 24784, Class 1: 788
#   After SMOTE  - Class 0: 24784, Class 1: 24784
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1141
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1211
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1257
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1058
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1114
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1205
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1064
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1135
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1265
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1045
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1113
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1192
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1141
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1370
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1517
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1436
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1376
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1368
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1400
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1352
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1215
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1295
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1306
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1279
# Best Params for label 5: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, PR-AUC: 0.1517
#
# Training model for label 7/13
#   Before SMOTE - Class 0: 24834, Class 1: 1050
#   After SMOTE  - Class 0: 24834, Class 1: 24834
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2739
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.2784
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2878
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.2951
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3041
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3133
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3008
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3081
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3282
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2954
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.2995
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3292
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2739
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3410
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3400
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3514
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3360
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3333
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3348
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3201
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3064
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3242
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.2983
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.2943
# Best Params for label 6: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, PR-AUC: 0.3514
#
# Training model for label 8/13
#   Before SMOTE - Class 0: 24953, Class 1: 4306
#   After SMOTE  - Class 0: 24953, Class 1: 24953
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.5063
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5139
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5222
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5277
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5308
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5368
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5260
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5313
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5352
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5228
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5297
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5378
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.5063
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5363
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5292
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5270
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5162
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5129
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5151
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5099
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5016
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5126
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5045
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5040
# Best Params for label 7: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, PR-AUC: 0.5378
#
# Training model for label 9/13
#   Before SMOTE - Class 0: 26732, Class 1: 2971
#   After SMOTE  - Class 0: 26732, Class 1: 26732
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.6373
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.6539
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.6544
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.6352
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.6459
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.6646
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.6386
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.6457
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.6517
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.6397
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.6458
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.6523
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.6373
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.6906
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.6866
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.6892
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.6801
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.6682
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.6798
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.6738
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.6645
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.6834
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.6571
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.6631
# Best Params for label 8: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, PR-AUC: 0.6906
#
# Training model for label 10/13
#   Before SMOTE - Class 0: 24709, Class 1: 384
#   After SMOTE  - Class 0: 24709, Class 1: 24709
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1578
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1947
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2281
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.2048
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1975
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.2057
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.2265
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.2097
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.2038
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2046
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1957
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.2008
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1578
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.2482
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2420
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.2487
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.2272
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.2277
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.2195
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.2350
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.2292
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2327
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.2455
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.2338
# Best Params for label 9: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, PR-AUC: 0.2487
#
# Training model for label 11/13
#   Before SMOTE - Class 0: 26674, Class 1: 1745
#   After SMOTE  - Class 0: 26674, Class 1: 26674
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2677
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.2746
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2801
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.2767
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.2992
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3022
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.2860
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.2937
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3011
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2852
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3019
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3185
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2677
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3336
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3294
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3322
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3344
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3280
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3251
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3233
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3260
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3252
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3163
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3107
# Best Params for label 10: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, PR-AUC: 0.3344
#
# Training model for label 12/13
#   Before SMOTE - Class 0: 26898, Class 1: 455
#   After SMOTE  - Class 0: 26898, Class 1: 26898
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1284
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1401
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1449
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1360
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1340
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1411
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1273
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1341
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1420
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1263
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1335
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1390
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1284
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1467
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1723
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1528
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1680
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1424
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1585
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1544
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1575
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1390
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1390
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1352
# Best Params for label 11: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, PR-AUC: 0.1723
#
# Training model for label 13/13
#   Before SMOTE - Class 0: 24940, Class 1: 1572
#   After SMOTE  - Class 0: 24940, Class 1: 24940
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4250
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.4434
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.4440
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.4339
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.4465
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.4445
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.4343
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.4545
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.4533
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.4255
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.4462
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.4528
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4250
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5254
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5170
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.4956
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.4907
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.4877
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.4833
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.4837
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.4936
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5051
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5044
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5042
# Best Params for label 12: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, PR-AUC: 0.5254

# %%
best_params_per_label
# Out:
# {0: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100},
#  1: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50},
#  2: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100},
#  3: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50},
#  4: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75},
#  5: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100},
#  6: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50},
#  7: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100},
#  8: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75},
#  9: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50},
#  10: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75},
#  11: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100},
#  12: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}}

# %%
 #initialise to have predictions for each label for each test
 predictions = np.zeros((test_embeddings.shape[0], num_labels))

# %%
for label_idx, model in models.items():
    print(f"Predicting for label {label_idx + 1}/{num_labels}")

    # Predict probabilities
    pred_probs = model.predict(test_embeddings)
    predictions[:, label_idx] = pred_probs
# Out:
# Predicting for label 1/13
# Predicting for label 2/13
# Predicting for label 3/13
# Predicting for label 4/13
# Predicting for label 5/13
# Predicting for label 6/13
# Predicting for label 7/13
# Predicting for label 8/13
# Predicting for label 9/13
# Predicting for label 10/13
# Predicting for label 11/13
# Predicting for label 12/13
# Predicting for label 13/13

# %%
# Convert predicted probabilities to binary (threshold = 0.5)
binary_predictions = (predictions > 0.5).astype(int)
masked_test_labels = np.where(np.isnan(test_labels), -1, test_labels)

# Compute classification report
for label_idx in range(num_labels):
    valid_idx = ~np.isnan(test_labels[:, label_idx])  # Get valid (non-NaN) indices
    y_true = test_labels[valid_idx, label_idx]
    y_pred = binary_predictions[valid_idx, label_idx]

    if len(y_true) > 0:  # Ensure we have valid samples
        print(f"\nLabel {label_idx} Metrics:")
        print(classification_report(y_true, y_pred, zero_division=0))
    else:
        print(f"\nLabel {label_idx}: No valid samples for evaluation.")
# Out:
# Label 0 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.85      0.90      3046
#          1.0       0.42      0.76      0.54       446
#
#     accuracy                           0.84      3492
#    macro avg       0.69      0.80      0.72      3492
# weighted avg       0.89      0.84      0.86      3492
#
#
# Label 1 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.87      0.92      3202
#          1.0       0.43      0.76      0.54       400
#
#     accuracy                           0.86      3602
#    macro avg       0.70      0.81      0.73      3602
# weighted avg       0.91      0.86      0.88      3602
#
#
# Label 2 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.91      0.95      3167
#          1.0       0.16      0.75      0.26        75
#
#     accuracy                           0.90      3242
#    macro avg       0.58      0.83      0.61      3242
# weighted avg       0.97      0.90      0.93      3242
#
#
# Label 3 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.94      0.97      3332
#          1.0       0.33      0.79      0.46       123
#
#     accuracy                           0.93      3455
#    macro avg       0.66      0.86      0.71      3455
# weighted avg       0.97      0.93      0.95      3455
#
#
# Label 4 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.87      0.92      3106
#          1.0       0.09      0.56      0.15        70
#
#     accuracy                           0.86      3176
#    macro avg       0.54      0.71      0.54      3176
# weighted avg       0.97      0.86      0.91      3176
#
#
# Label 5 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.85      0.91      3047
#          1.0       0.08      0.49      0.13        82
#
#     accuracy                           0.84      3129
#    macro avg       0.53      0.67      0.52      3129
# weighted avg       0.96      0.84      0.89      3129
#
#
# Label 6 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.88      0.93      3057
#          1.0       0.19      0.72      0.31       120
#
#     accuracy                           0.88      3177
#    macro avg       0.59      0.80      0.62      3177
# weighted avg       0.96      0.88      0.91      3177
#
#
# Label 7 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.82      0.88      3068
#          1.0       0.44      0.74      0.55       576
#
#     accuracy                           0.81      3644
#    macro avg       0.69      0.78      0.72      3644
# weighted avg       0.86      0.81      0.83      3644
#
#
# Label 8 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.89      0.94      3295
#          1.0       0.49      0.85      0.62       393
#
#     accuracy                           0.89      3688
#    macro avg       0.73      0.87      0.78      3688
# weighted avg       0.93      0.89      0.90      3688
#
#
# Label 9 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.94      0.97      3038
#          1.0       0.14      0.64      0.23        44
#
#     accuracy                           0.94      3082
#    macro avg       0.57      0.79      0.60      3082
# weighted avg       0.98      0.94      0.96      3082
#
#
# Label 10 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.87      0.92      3310
#          1.0       0.24      0.61      0.35       226
#
#     accuracy                           0.85      3536
#    macro avg       0.61      0.74      0.63      3536
# weighted avg       0.92      0.85      0.88      3536
#
#
# Label 11 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.91      0.95      3341
#          1.0       0.12      0.69      0.20        55
#
#     accuracy                           0.91      3396
#    macro avg       0.56      0.80      0.58      3396
# weighted avg       0.98      0.91      0.94      3396
#
#
# Label 12 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.87      0.93      3067
#          1.0       0.30      0.82      0.44       201
#
#     accuracy                           0.87      3268
#    macro avg       0.64      0.85      0.68      3268
# weighted avg       0.94      0.87      0.90      3268

# %%
pr_auc_scores = []

for label_idx in range(num_labels):
    valid_idx = ~np.isnan(test_labels[:, label_idx])

    if valid_idx.sum() > 0:  # Ensure there are valid labels
        pr_auc = average_precision_score(
            test_labels[valid_idx, label_idx],
            predictions[valid_idx, label_idx]
        )
        pr_auc_scores.append(pr_auc)
        print(f"Label {label_idx}: PR-AUC = {pr_auc:.4f}")
# Out:
# Label 0: PR-AUC = 0.3531
# Label 1: PR-AUC = 0.3493
# Label 2: PR-AUC = 0.1246
# Label 3: PR-AUC = 0.2642
# Label 4: PR-AUC = 0.0576
# Label 5: PR-AUC = 0.0515
# Label 6: PR-AUC = 0.1509
# Label 7: PR-AUC = 0.3682
# Label 8: PR-AUC = 0.4306
# Label 9: PR-AUC = 0.0956
# Label 10: PR-AUC = 0.1727
# Label 11: PR-AUC = 0.0865
# Label 12: PR-AUC = 0.2555

# %% [markdown]
# **without SMOTE**

# %%
#get number of labels
num_labels = train_labels.shape[1]

# %%
# Compare to no SMOTE
# Train one model per label, each model for each label is a binary task
models = {}
best_params_per_label = {}

# Define param grid
param_list = [
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": 5, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": 5, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": 5, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": 7, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": 7, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": 7, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": -1, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": -1, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": -1, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": 3, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": 3, "n_estimators": 100},
    {"learning_rate": 0.1, "max_depth": 5, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": 5, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": 5, "n_estimators": 100},
    {"learning_rate": 0.1, "max_depth": 7, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": 7, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": 7, "n_estimators": 100},
    {"learning_rate": 0.1, "max_depth": -1, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": -1, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": -1, "n_estimators": 100},

]

for label_idx in range(num_labels):
    print(f"\nTraining model for label {label_idx + 1}/{num_labels}")

    # Filter for non-NA samples for this label in train and validation sets
    train_idx = ~np.isnan(train_labels[:, label_idx])
    val_idx = ~np.isnan(valid_labels[:, label_idx])

    x_train = train_embeddings[train_idx]
    y_train = train_labels[train_idx, label_idx].astype(int)

    x_val = valid_embeddings[val_idx]
    y_val = valid_labels[val_idx, label_idx].astype(int)

    best_pr_auc = 0
    best_model = None
    best_params = None

    for params in param_list:
        model = LGBMClassifier(objective="binary", boosting_type="gbdt", verbose=-1, **params)
        model.fit(x_train, y_train)

        val_probs = model.predict_proba(x_val)[:, 1]
        pr_auc = average_precision_score(y_val, val_probs)
        #auc = roc_auc_score(y_val, val_probs)

        print(f"  Params: {params}, Validation PR-AUC: {pr_auc:.4f}")

        if pr_auc > best_pr_auc:
            best_pr_auc = pr_auc
            best_model = model
            best_params = params

    print(f"Best Params for label {label_idx}: {best_params}, PR-AUC: {best_pr_auc:.4f}")
    models[label_idx] = best_model
    best_params_per_label[label_idx] = best_params
# Out:
# Training model for label 1/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.5224
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5270
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5297
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5163
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5235
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5264
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5147
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5212
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5262
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5126
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5187
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5229
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.5224
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5383
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5449
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5351
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5348
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5337
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5245
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5210
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5260
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5379
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5288
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5235
# Best Params for label 0: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, PR-AUC: 0.5449
#
# Training model for label 2/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.5115
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5184
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5252
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5328
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5400
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5464
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5410
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5479
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5541
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5358
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5438
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5509
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.5115
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5457
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5448
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5349
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5359
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5380
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5447
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5487
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5590
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5546
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5526
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5512
# Best Params for label 1: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, PR-AUC: 0.5590
#
# Training model for label 3/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3608
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3607
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3689
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3767
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3839
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3931
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3629
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3716
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3731
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3958
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3890
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3917
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3608
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3556
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3390
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3162
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3035
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3031
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3090
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3073
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3065
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2678
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.2828
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.2880
# Best Params for label 2: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, PR-AUC: 0.3958
#
# Training model for label 4/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3562
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3565
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3621
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3934
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3980
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.4005
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3704
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3839
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3798
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3615
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3721
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3743
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3562
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3624
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3604
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3855
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3951
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3994
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3785
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3957
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3961
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3905
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3873
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3794
# Best Params for label 3: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, PR-AUC: 0.4005
#
# Training model for label 5/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1726
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1766
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1721
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.2034
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1914
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1953
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1558
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1606
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1586
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1729
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1768
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1759
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1726
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1540
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1517
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1282
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1348
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1327
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1069
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1053
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1099
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1210
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1228
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1296
# Best Params for label 4: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, PR-AUC: 0.2034
#
# Training model for label 6/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1333
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1390
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1453
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1242
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1285
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1381
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1345
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1420
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1482
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1545
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1554
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1561
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1333
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1256
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1280
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1339
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1295
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1288
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1318
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1232
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1324
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1068
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1091
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1106
# Best Params for label 5: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, PR-AUC: 0.1561
#
# Training model for label 7/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3169
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3168
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3211
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3726
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3660
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3621
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3643
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3568
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3567
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3607
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3568
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3573
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3169
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3441
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3416
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3199
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3132
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3125
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3285
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3273
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3247
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3258
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3321
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3347
# Best Params for label 6: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, PR-AUC: 0.3726
#
# Training model for label 8/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.5056
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5180
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5255
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5137
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5211
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5266
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5234
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5261
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5281
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5219
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5255
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5290
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.5056
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5445
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5432
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5287
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5300
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5250
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5234
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5221
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5249
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5182
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5150
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5184
# Best Params for label 7: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, PR-AUC: 0.5445
#
# Training model for label 9/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.6737
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.6832
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.6904
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.6646
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.6820
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.6838
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.6801
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.6879
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.6914
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.6767
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.6844
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.6856
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.6737
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.7024
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.6975
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.6875
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.6954
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.6908
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.6749
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.6852
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.6849
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.6937
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.6829
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.6876
# Best Params for label 8: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, PR-AUC: 0.7024
#
# Training model for label 10/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2913
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.2971
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2949
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.2589
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.2551
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.2588
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.2525
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.2564
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.2565
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2616
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.2651
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.2652
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2913
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.2158
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2134
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1753
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1863
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1937
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.2390
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.2436
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.2505
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1677
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1885
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.2076
# Best Params for label 9: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, PR-AUC: 0.2971
#
# Training model for label 11/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3409
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3480
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3538
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3414
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3448
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3489
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3487
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3478
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3565
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3591
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3605
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3661
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3409
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3605
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3565
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3494
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3535
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3495
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3439
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3529
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3505
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3385
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3437
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3431
# Best Params for label 10: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, PR-AUC: 0.3661
#
# Training model for label 12/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1736
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1765
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1728
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1806
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1841
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1757
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1658
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1612
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1588
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2056
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.2047
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.2015
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1736
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1620
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1651
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1680
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1778
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1817
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1564
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1703
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1659
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1504
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1505
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1641
# Best Params for label 11: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, PR-AUC: 0.2056
#
# Training model for label 13/13
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4826
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.4917
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5019
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5029
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5074
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5150
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.4917
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5001
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5001
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.4886
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.4904
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.4948
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4826
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5187
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5168
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5014
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5014
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5004
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5198
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5227
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5087
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5333
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5210
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5203
# Best Params for label 12: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, PR-AUC: 0.5333

# %%
best_params_per_label
# Out:
# {0: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100},
#  1: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100},
#  2: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50},
#  3: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100},
#  4: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50},
#  5: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100},
#  6: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50},
#  7: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75},
#  8: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75},
#  9: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75},
#  10: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100},
#  11: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50},
#  12: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}}

# %%
 #initialise to have predictions for each label for each test
 predictions = np.zeros((test_embeddings.shape[0], num_labels))

# %%
for label_idx, model in models.items():
    print(f"Predicting for label {label_idx + 1}/{num_labels}")

    # Predict probabilities
    pred_probs = model.predict(test_embeddings)
    predictions[:, label_idx] = pred_probs
# Out:
# Predicting for label 1/13
# Predicting for label 2/13
# Predicting for label 3/13
# Predicting for label 4/13
# Predicting for label 5/13
# Predicting for label 6/13
# Predicting for label 7/13
# Predicting for label 8/13
# Predicting for label 9/13
# Predicting for label 10/13
# Predicting for label 11/13
# Predicting for label 12/13
# Predicting for label 13/13

# %%
# Convert predicted probabilities to binary (threshold = 0.5)
binary_predictions = (predictions > 0.5).astype(int)
masked_test_labels = np.where(np.isnan(test_labels), -1, test_labels)

# Compute classification report
for label_idx in range(num_labels):
    valid_idx = ~np.isnan(test_labels[:, label_idx])  # Get valid (non-NaN) indices
    y_true = test_labels[valid_idx, label_idx]
    y_pred = binary_predictions[valid_idx, label_idx]

    if len(y_true) > 0:  # Ensure we have valid samples
        print(f"\nLabel {label_idx} Metrics:")
        print(classification_report(y_true, y_pred, zero_division=0))
    else:
        print(f"\nLabel {label_idx}: No valid samples for evaluation.")
# Out:
# Label 0 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.96      0.94      3046
#          1.0       0.60      0.42      0.49       446
#
#     accuracy                           0.89      3492
#    macro avg       0.76      0.69      0.72      3492
# weighted avg       0.88      0.89      0.88      3492
#
#
# Label 1 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.97      0.95      3202
#          1.0       0.62      0.39      0.48       400
#
#     accuracy                           0.91      3602
#    macro avg       0.77      0.68      0.71      3602
# weighted avg       0.89      0.91      0.90      3602
#
#
# Label 2 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      3167
#          1.0       0.00      0.00      0.00        75
#
#     accuracy                           0.98      3242
#    macro avg       0.49      0.50      0.49      3242
# weighted avg       0.95      0.98      0.97      3242
#
#
# Label 3 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98      3332
#          1.0       1.00      0.01      0.02       123
#
#     accuracy                           0.96      3455
#    macro avg       0.98      0.50      0.50      3455
# weighted avg       0.97      0.96      0.95      3455
#
#
# Label 4 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      3106
#          1.0       0.00      0.00      0.00        70
#
#     accuracy                           0.98      3176
#    macro avg       0.49      0.50      0.49      3176
# weighted avg       0.96      0.98      0.97      3176
#
#
# Label 5 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.99      3047
#          1.0       0.00      0.00      0.00        82
#
#     accuracy                           0.97      3129
#    macro avg       0.49      0.50      0.49      3129
# weighted avg       0.95      0.97      0.96      3129
#
#
# Label 6 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98      3057
#          1.0       0.00      0.00      0.00       120
#
#     accuracy                           0.96      3177
#    macro avg       0.48      0.50      0.49      3177
# weighted avg       0.93      0.96      0.94      3177
#
#
# Label 7 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.95      0.92      3068
#          1.0       0.60      0.36      0.45       576
#
#     accuracy                           0.86      3644
#    macro avg       0.74      0.66      0.69      3644
# weighted avg       0.84      0.86      0.85      3644
#
#
# Label 8 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.97      0.96      3295
#          1.0       0.69      0.60      0.64       393
#
#     accuracy                           0.93      3688
#    macro avg       0.82      0.78      0.80      3688
# weighted avg       0.92      0.93      0.93      3688
#
#
# Label 9 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      3038
#          1.0       0.00      0.00      0.00        44
#
#     accuracy                           0.99      3082
#    macro avg       0.49      0.50      0.50      3082
# weighted avg       0.97      0.99      0.98      3082
#
#
# Label 10 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97      3310
#          1.0       1.00      0.03      0.06       226
#
#     accuracy                           0.94      3536
#    macro avg       0.97      0.52      0.51      3536
# weighted avg       0.94      0.94      0.91      3536
#
#
# Label 11 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      3341
#          1.0       0.00      0.00      0.00        55
#
#     accuracy                           0.98      3396
#    macro avg       0.49      0.50      0.50      3396
# weighted avg       0.97      0.98      0.98      3396
#
#
# Label 12 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.97      3067
#          1.0       0.49      0.27      0.35       201
#
#     accuracy                           0.94      3268
#    macro avg       0.72      0.63      0.66      3268
# weighted avg       0.93      0.94      0.93      3268

# %%
pr_auc_scores = []

for label_idx in range(num_labels):
    valid_idx = ~np.isnan(test_labels[:, label_idx])

    if valid_idx.sum() > 0:  # Ensure there are valid labels
        pr_auc = average_precision_score(
            test_labels[valid_idx, label_idx],
            predictions[valid_idx, label_idx]
        )
        pr_auc_scores.append(pr_auc)
        print(f"Label {label_idx}: PR-AUC = {pr_auc:.4f}")
# Out:
# Label 0: PR-AUC = 0.3271
# Label 1: PR-AUC = 0.3064
# Label 2: PR-AUC = 0.0231
# Label 3: PR-AUC = 0.0434
# Label 4: PR-AUC = 0.0220
# Label 5: PR-AUC = 0.0262
# Label 6: PR-AUC = 0.0378
# Label 7: PR-AUC = 0.3179
# Label 8: PR-AUC = 0.4549
# Label 9: PR-AUC = 0.0143
# Label 10: PR-AUC = 0.0929
# Label 11: PR-AUC = 0.0162
# Label 12: PR-AUC = 0.1769

# %% [markdown]
# **Run lgbm with feature selection and smote for reduced feature set:**

# %%
import pickle
from imblearn.over_sampling import SMOTE
import numpy as np
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, roc_auc_score, average_precision_score
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
with open('/content/drive/MyDrive/SPH6004_project/data/X_train_100d_UMAP_AE.pkl', 'rb') as f:
    train_embeddings = pickle.load(f)

with open('/content/drive/MyDrive/SPH6004_project/data/y_train.pkl', 'rb') as f:
    train_labels = pickle.load(f)

with open('/content/drive/MyDrive/SPH6004_project/data/X_valid_100d_UMAP_AE.pkl', 'rb') as f:
    valid_embeddings = pickle.load(f)

with open('/content/drive/MyDrive/SPH6004_project/data/y_valid.pkl', 'rb') as f:
    valid_labels = pickle.load(f)

with open('/content/drive/MyDrive/SPH6004_project/data/X_test_100d_UMAP_AE.pkl', 'rb') as f:
    test_embeddings = pickle.load(f)

with open('/content/drive/MyDrive/SPH6004_project/data/y_test.pkl', 'rb') as f:
    test_labels = pickle.load(f)

# %%
train_embeddings = np.array(train_embeddings)
train_labels = np.array(train_labels)
valid_embeddings = np.array(valid_embeddings)
valid_labels = np.array(valid_labels)

train_embeddings.shape
# Out:
# (36502, 100)

# %%
train_embeddings.shape
# Out:
# (36502, 100)

# %%
test_embeddings.shape
# Out:
# (4562, 100)

# %%
train_labels.shape
# Out:
# (36502, 13)

# %%
valid_labels.shape
# Out:
# (4563, 13)

# %%
test_labels.shape
# Out:
# (4562, 13)

# %%
#get number of labels
num_labels = train_labels.shape[1]

# %%
# Train one model per label, each model for each label is a binary task
models = {}
best_params_per_label = {}

# Define param grid
param_list = [
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": 5, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": 5, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": 5, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": 7, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": 7, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": 7, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": -1, "n_estimators": 50},
    {"learning_rate": 0.01, "max_depth": -1, "n_estimators": 75},
    {"learning_rate": 0.01, "max_depth": -1, "n_estimators": 100},
    {"learning_rate": 0.01, "max_depth": 3, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": 3, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": 3, "n_estimators": 100},
    {"learning_rate": 0.1, "max_depth": 5, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": 5, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": 5, "n_estimators": 100},
    {"learning_rate": 0.1, "max_depth": 7, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": 7, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": 7, "n_estimators": 100},
    {"learning_rate": 0.1, "max_depth": -1, "n_estimators": 50},
    {"learning_rate": 0.1, "max_depth": -1, "n_estimators": 75},
    {"learning_rate": 0.1, "max_depth": -1, "n_estimators": 100},

]

for label_idx in range(num_labels):
    print(f"\nTraining model for label {label_idx + 1}/{num_labels}")

    # Filter for non-NA samples for this label in train and validation sets
    train_idx = ~np.isnan(train_labels[:, label_idx])
    val_idx = ~np.isnan(valid_labels[:, label_idx])

    x_train = train_embeddings[train_idx]
    y_train = train_labels[train_idx, label_idx].astype(int)

    x_val = valid_embeddings[val_idx]
    y_val = valid_labels[val_idx, label_idx].astype(int)

    # Check class distribution before SMOTE
    class_0, class_1 = np.bincount(y_train)
    print(f"  Before SMOTE - Class 0: {class_0}, Class 1: {class_1}")

    smote = SMOTE(sampling_strategy='auto', random_state=42)
    x_train, y_train = smote.fit_resample(x_train, y_train)

    # Check class distribution after SMOTE
    class_0_res, class_1_res = np.bincount(y_train)
    print(f"  After SMOTE  - Class 0: {class_0_res}, Class 1: {class_1_res}")

    best_pr_auc = 0
    best_model = None
    best_params = None

    for params in param_list:
        model = LGBMClassifier(objective="binary", boosting_type="gbdt", verbose=-1, **params)
        model.fit(x_train, y_train)

        val_probs = model.predict_proba(x_val)[:, 1]
        pr_auc = average_precision_score(y_val, val_probs)
        #auc = roc_auc_score(y_val, val_probs)

        print(f"  Params: {params}, Validation PR-AUC: {pr_auc:.4f}")

        if pr_auc > best_pr_auc:
            best_pr_auc = pr_auc
            best_model = model
            best_params = params

    print(f"Best Params for label {label_idx}: {best_params}, PR-AUC: {best_pr_auc:.4f}")
    models[label_idx] = best_model
    best_params_per_label[label_idx] = best_params
# Out:
# Training model for label 1/13
#   Before SMOTE - Class 0: 24778, Class 1: 3222
#   After SMOTE  - Class 0: 24778, Class 1: 24778
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4099
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.4351
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.4664
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.4601
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.4651
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.4650
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.4721
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.4747
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.4768
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.4746
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.4785
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.4817
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4099
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5134
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5180
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5055
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5068
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5000
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5066
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5018
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.4944
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5129
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5111
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5111
# Best Params for label 0: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, PR-AUC: 0.5180
#
# Training model for label 2/13
#   Before SMOTE - Class 0: 25852, Class 1: 2982
#   After SMOTE  - Class 0: 25852, Class 1: 25852
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3958
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.4033
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.4245
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.4258
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.4544
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.4615
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.4638
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.4725
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.4852
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.4641
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.4841
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.4920
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3958
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5178
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5207
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5190
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5246
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5304
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5344
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5320
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5288
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5180
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5191
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5142
# Best Params for label 1: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, PR-AUC: 0.5344
#
# Training model for label 3/13
#   Before SMOTE - Class 0: 25851, Class 1: 650
#   After SMOTE  - Class 0: 25851, Class 1: 25851
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2069
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.2260
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2433
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.2213
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.2460
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.2570
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.2373
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.2592
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.2594
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2361
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.2599
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.2622
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2069
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3002
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2928
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3041
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3000
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.2740
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3003
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3005
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.2908
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2894
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.2696
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.2643
# Best Params for label 2: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, PR-AUC: 0.3041
#
# Training model for label 4/13
#   Before SMOTE - Class 0: 26884, Class 1: 928
#   After SMOTE  - Class 0: 26884, Class 1: 26884
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2155
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.2129
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2301
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.2634
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.2842
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.2952
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.2964
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.2897
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.2956
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2964
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.2997
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3038
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2155
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3586
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3679
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3706
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3662
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3595
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3507
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3433
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3392
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3464
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3417
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3297
# Best Params for label 3: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, PR-AUC: 0.3706
#
# Training model for label 5/13
#   Before SMOTE - Class 0: 25213, Class 1: 553
#   After SMOTE  - Class 0: 25213, Class 1: 25213
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1006
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1284
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1347
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1409
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1441
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1434
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1472
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1506
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1532
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1498
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1528
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1553
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1006
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1487
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1657
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1637
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1467
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1388
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1584
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1296
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1248
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1565
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1235
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1150
# Best Params for label 4: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, PR-AUC: 0.1657
#
# Training model for label 6/13
#   Before SMOTE - Class 0: 24784, Class 1: 788
#   After SMOTE  - Class 0: 24784, Class 1: 24784
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.0795
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.0846
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.0891
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.0900
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1048
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1043
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.0897
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1063
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1169
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.0894
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1046
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1110
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.0795
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1238
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1235
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1226
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1251
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1240
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1331
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1267
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1207
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1224
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1217
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1150
# Best Params for label 5: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, PR-AUC: 0.1331
#
# Training model for label 7/13
#   Before SMOTE - Class 0: 24834, Class 1: 1050
#   After SMOTE  - Class 0: 24834, Class 1: 24834
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2484
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.2955
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2959
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.2751
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.2983
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3078
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.2833
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.2961
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3065
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2847
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3008
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3076
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.2484
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3367
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3354
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3317
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3361
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3285
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3238
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3188
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3116
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3330
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3196
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3207
# Best Params for label 6: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, PR-AUC: 0.3367
#
# Training model for label 8/13
#   Before SMOTE - Class 0: 24953, Class 1: 4306
#   After SMOTE  - Class 0: 24953, Class 1: 24953
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4212
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.4602
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.4730
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.4707
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.4755
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.4809
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.4790
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.4850
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.4878
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.4805
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.4825
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.4861
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4212
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.5050
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5064
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5038
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5028
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5033
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5051
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5062
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.4996
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5055
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5044
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.5017
# Best Params for label 7: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, PR-AUC: 0.5064
#
# Training model for label 9/13
#   Before SMOTE - Class 0: 26732, Class 1: 2971
#   After SMOTE  - Class 0: 26732, Class 1: 26732
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4727
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.4764
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.5233
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.5103
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.5411
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.5669
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5417
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.5593
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.5680
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5707
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.5850
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.6001
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.4727
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.6446
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.6478
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.6322
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.6396
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.6470
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.6341
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.6236
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.6202
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.6377
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.6400
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.6366
# Best Params for label 8: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, PR-AUC: 0.6478
#
# Training model for label 10/13
#   Before SMOTE - Class 0: 24709, Class 1: 384
#   After SMOTE  - Class 0: 24709, Class 1: 24709
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.0890
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.0951
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1006
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1226
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1334
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1329
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1339
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1481
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1518
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1460
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1600
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1734
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.0890
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1925
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2188
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1998
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1933
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1898
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1786
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1901
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1800
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2002
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1923
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1944
# Best Params for label 9: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, PR-AUC: 0.2188
#
# Training model for label 11/13
#   Before SMOTE - Class 0: 26674, Class 1: 1745
#   After SMOTE  - Class 0: 26674, Class 1: 26674
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1975
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.2362
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.2474
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.2442
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.2630
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.2882
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.2948
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3065
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3062
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.2969
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3073
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3046
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1975
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3141
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.3204
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.3234
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.3384
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.3412
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.3212
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.3292
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.3259
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.3279
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.3361
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.3353
# Best Params for label 10: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, PR-AUC: 0.3412
#
# Training model for label 12/13
#   Before SMOTE - Class 0: 26898, Class 1: 455
#   After SMOTE  - Class 0: 26898, Class 1: 26898
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1015
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1113
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1197
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1248
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1221
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1251
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1211
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1352
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1402
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1283
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1390
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1430
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.1015
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.1592
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.1446
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.1428
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.1208
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.1222
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.1237
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.1350
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.1236
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.1566
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.1395
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.1394
# Best Params for label 11: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, PR-AUC: 0.1592
#
# Training model for label 13/13
#   Before SMOTE - Class 0: 24940, Class 1: 1572
#   After SMOTE  - Class 0: 24940, Class 1: 24940
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3995
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.3962
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.4089
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.4120
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.4207
#   Params: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.4304
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.4223
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.4236
#   Params: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.4352
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.4179
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.4262
#   Params: {'learning_rate': 0.01, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.4366
#   Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}, Validation PR-AUC: 0.3995
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 75}, Validation PR-AUC: 0.4908
#   Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}, Validation PR-AUC: 0.4949
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}, Validation PR-AUC: 0.4957
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 75}, Validation PR-AUC: 0.4816
#   Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}, Validation PR-AUC: 0.4999
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, Validation PR-AUC: 0.5114
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 75}, Validation PR-AUC: 0.4953
#   Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}, Validation PR-AUC: 0.4909
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 50}, Validation PR-AUC: 0.5000
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 75}, Validation PR-AUC: 0.4711
#   Params: {'learning_rate': 0.1, 'max_depth': -1, 'n_estimators': 100}, Validation PR-AUC: 0.4531
# Best Params for label 12: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 50}, PR-AUC: 0.5114

# %%
 #initialise to have predictions for each label for each test
 predictions = np.zeros((test_embeddings.shape[0], num_labels))

# %%
for label_idx, model in models.items():
    print(f"Predicting for label {label_idx + 1}/{num_labels}")

    # Predict probabilities
    pred_probs = model.predict(test_embeddings)
    predictions[:, label_idx] = pred_probs
# Out:
# Predicting for label 1/13
# Predicting for label 2/13
# Predicting for label 3/13
# Predicting for label 4/13
# Predicting for label 5/13
# Predicting for label 6/13
# Predicting for label 7/13
# Predicting for label 8/13
# Predicting for label 9/13
# Predicting for label 10/13
# Predicting for label 11/13
# Predicting for label 12/13
# Predicting for label 13/13

# %%
# Convert predicted probabilities to binary (threshold = 0.5)
binary_predictions = (predictions > 0.5).astype(int)
masked_test_labels = np.where(np.isnan(test_labels), -1, test_labels)

# Compute classification report
for label_idx in range(num_labels):
    valid_idx = ~np.isnan(test_labels[:, label_idx])  # Get valid (non-NaN) indices
    y_true = test_labels[valid_idx, label_idx]
    y_pred = binary_predictions[valid_idx, label_idx]

    if len(y_true) > 0:  # Ensure we have valid samples
        print(f"\nLabel {label_idx} Metrics:")
        print(classification_report(y_true, y_pred, zero_division=0))
    else:
        print(f"\nLabel {label_idx}: No valid samples for evaluation.")
# Out:
# Label 0 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.82      0.89      3046
#          1.0       0.40      0.80      0.53       446
#
#     accuracy                           0.82      3492
#    macro avg       0.68      0.81      0.71      3492
# weighted avg       0.89      0.82      0.84      3492
#
#
# Label 1 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.82      0.89      3202
#          1.0       0.36      0.80      0.50       400
#
#     accuracy                           0.82      3602
#    macro avg       0.67      0.81      0.69      3602
# weighted avg       0.90      0.82      0.85      3602
#
#
# Label 2 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.88      0.93      3167
#          1.0       0.13      0.75      0.22        75
#
#     accuracy                           0.88      3242
#    macro avg       0.56      0.81      0.58      3242
# weighted avg       0.97      0.88      0.92      3242
#
#
# Label 3 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.89      0.94      3332
#          1.0       0.23      0.88      0.36       123
#
#     accuracy                           0.89      3455
#    macro avg       0.61      0.88      0.65      3455
# weighted avg       0.97      0.89      0.92      3455
#
#
# Label 4 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.80      0.89      3106
#          1.0       0.07      0.67      0.13        70
#
#     accuracy                           0.80      3176
#    macro avg       0.53      0.74      0.51      3176
# weighted avg       0.97      0.80      0.87      3176
#
#
# Label 5 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.82      0.89      3047
#          1.0       0.07      0.49      0.12        82
#
#     accuracy                           0.81      3129
#    macro avg       0.53      0.65      0.51      3129
# weighted avg       0.96      0.81      0.87      3129
#
#
# Label 6 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.81      0.89      3057
#          1.0       0.14      0.75      0.23       120
#
#     accuracy                           0.81      3177
#    macro avg       0.56      0.78      0.56      3177
# weighted avg       0.96      0.81      0.87      3177
#
#
# Label 7 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.80      0.87      3068
#          1.0       0.42      0.74      0.53       576
#
#     accuracy                           0.79      3644
#    macro avg       0.68      0.77      0.70      3644
# weighted avg       0.86      0.79      0.82      3644
#
#
# Label 8 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.87      0.92      3295
#          1.0       0.45      0.87      0.59       393
#
#     accuracy                           0.87      3688
#    macro avg       0.72      0.87      0.76      3688
# weighted avg       0.93      0.87      0.89      3688
#
#
# Label 9 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.88      0.93      3038
#          1.0       0.08      0.75      0.15        44
#
#     accuracy                           0.88      3082
#    macro avg       0.54      0.81      0.54      3082
# weighted avg       0.98      0.88      0.92      3082
#
#
# Label 10 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.82      0.89      3310
#          1.0       0.20      0.67      0.31       226
#
#     accuracy                           0.81      3536
#    macro avg       0.59      0.74      0.60      3536
# weighted avg       0.92      0.81      0.85      3536
#
#
# Label 11 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.87      0.93      3341
#          1.0       0.09      0.78      0.17        55
#
#     accuracy                           0.87      3396
#    macro avg       0.54      0.83      0.55      3396
# weighted avg       0.98      0.87      0.92      3396
#
#
# Label 12 Metrics:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.87      0.92      3067
#          1.0       0.29      0.79      0.42       201
#
#     accuracy                           0.87      3268
#    macro avg       0.64      0.83      0.67      3268
# weighted avg       0.94      0.87      0.89      3268

# %%
pr_auc_scores = []

for label_idx in range(num_labels):
    valid_idx = ~np.isnan(test_labels[:, label_idx])

    if valid_idx.sum() > 0:  # Ensure there are valid labels
        pr_auc = average_precision_score(
            test_labels[valid_idx, label_idx],
            predictions[valid_idx, label_idx]
        )
        pr_auc_scores.append(pr_auc)
        print(f"Label {label_idx}: PR-AUC = {pr_auc:.4f}")
# Out:
# Label 0: PR-AUC = 0.3452
# Label 1: PR-AUC = 0.3113
# Label 2: PR-AUC = 0.1033
# Label 3: PR-AUC = 0.2031
# Label 4: PR-AUC = 0.0554
# Label 5: PR-AUC = 0.0462
# Label 6: PR-AUC = 0.1122
# Label 7: PR-AUC = 0.3491
# Label 8: PR-AUC = 0.4040
# Label 9: PR-AUC = 0.0647
# Label 10: PR-AUC = 0.1550
# Label 11: PR-AUC = 0.0765
# Label 12: PR-AUC = 0.2399
